# %%
# API key "AIzaSyDhCmpvx6NYi84Z7MWal-pEy2KGfhlug_Q"

# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
#API key connection
def Api_connect():
    Api_Id="AIzaSyDhCmpvx6NYi84Z7MWal-pEy2KGfhlug_Q"

    api_service_name="youtube"
    api_versions="v3"

    youtube=build(api_service_name,api_versions,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %%
#Get Channel information
def get_channel_info(channel_id):
    request=youtube.channels().list(
                part="snippet,ContentDetails,statistics",
                id=channel_id
)
    response=request.execute()

    for i in response['items']:
        data=dict(Channel_name=i["snippet"]["title"],
                Channel_Id=i["id"],
                Subscribers=i['statistics']['subscriberCount'],
                Views=i["statistics"]["viewCount"],
                Total_Videos=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]["description"],
                Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data
    print(data)

# %%
channel_details=get_channel_info("UC2J_VKrAzOEJuQvFFtj3KUw")

# %%
channel_details
# Out:
# {'Channel_name': 'Chennai Super Kings',
#  'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#  'Subscribers': '3220000',
#  'Views': '641860992',
#  'Total_Videos': '1157',
#  'Channel_Description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove',
#  'Playlist_Id': 'UU2J_VKrAzOEJuQvFFtj3KUw'}

# %%
# Get video ids
def get_videos_ids(channel_id):
    video_ids = []
    response = youtube.channels().list(id=channel_id, part='contentDetails').execute()
    Playlist_Id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token = None

    while True:
        response1 = youtube.playlistItems().list(
            part='snippet',
            playlistId=Playlist_Id,
            maxResults=50,
            pageToken=next_page_token
        ).execute()

        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])

        next_page_token = response1.get('nextPageToken')

        if next_page_token is None:
            break

    return video_ids

# %%
Video_Ids=get_videos_ids('UC2J_VKrAzOEJuQvFFtj3KUw')

# %%
Video_Ids
# Out:
# ['KJsCG-Ho8OU',
#  'wXvNBd0J_a8',
#  'Rzvw1q7l2FA',
#  '9W4FqLKy4Gk',
#  'vBCbzWmXpcA',
#  '5UpeKysSTS4',
#  '-FzGywV6bl8',
#  '38hCJ9W5hB0',
#  'u5SGrSWwx7s',
#  'lGgMw1Cniq4',
#  'ne9u_8R8F-E',
#  'JP5_oh60rVE',
#  'MQgYm4gm1V4',
#  'xnEdfZo-2PI',
#  'DhvBzXWwR1w',
#  'zAyvCEowEnk',
#  'vjDoOlWBJp0',
#  'MRe9L6HxRvo',
#  'bwy8VYlROvc',
#  '0bmEvVq7Ws8',
#  '6ddd1yXsWK0',
#  'wJNX3ZlaUkQ',
#  'YwSJggqfPGs',
#  'Ri5Gnml8jNc',
#  'wIUTD1FTnus',
#  '8oH0atPDiwY',
#  'kZ1gzu3IxGg',
#  's-hLe2bZeRs',
#  '0xxMPPGuhL8',
#  'fha8LqqIPPw',
#  '4twOsBNsEHc',
#  'YAbB6MTV-Sw',
#  'iBUYK18u7dI',
#  '_AzP2F64qiQ',
#  'j--OAtEOFPs',
#  'uIBy9dSPJXc',
#  'c-Elhx5OyH4',
#  '7yqd_b-cSHo',
#  'PNgsFF8daGY',
#  '8hbxvnj-02E',
#  '9LxOTWZawoU',
#  'KOGmZxI9jJw',
#  '98brRsgZ5cE',
#  '8CoILI6ThNc',
#  'b3-rS0baUrA',
#  '7CsqpL0R5J0',
#  'e4yOuMhD7xY',
#  'QaxBNasNL_s',
#  'AVNLIYL23go',
#  'xWx0KTT_lYI',
#  '5ksUpqdLHfc',
#  'WB4Ml8yjC2k',
#  'rXT9J3j0mPY',
#  '98W-G7hEPvY',
#  '2jU1xTBLBGs',
#  'lqjFpog8ZcA',
#  'KVhfaeC1LN4',
#  'w1tx7gH4-2w',
#  'fx8PhBgkiv8',
#  'baLQHOTWm3o',
#  'Erkjh_RM5y0',
#  'm_wYkpVaWCs',
#  'HYzJBwP40t0',
#  '6zv8mzeqZn0',
#  'IjsR8UBoUkE',
#  'f1gnaV4sWYo',
#  '85adJ60bQqk',
#  'zdZmopaH8vA',
#  'r88fWNdYmPc',
#  'o29L2ysDYeY',
#  'DntAi1keBkg',
#  'sWldDPznq60',
#  'R6v4PyiDOMI',
#  '51BFx3J2Ru4',
#  'xlripGf89Aw',
#  'Q4wsTEV8_XM',
#  'XZ0n5vOCj6U',
#  'W4P5AyK7Ues',
#  'RtD4q4LnLUw',
#  'WxbZtVJLID4',
#  '9OPmzW31nzk',
#  'MbzuFYeq4aU',
#  'fGHl5k_PyNE',
#  'g87iuCiFM0E',
#  '1QyC0VyxjUA',
#  'JNs4p0pk8Ms',
#  'dsMLIZKIEd8',
#  'QJNsvEta0UI',
#  'iVWyETew2KM',
#  '0b6rhoi1pAQ',
#  'RF3gM9MUPwk',
#  'FCJyVOtupZg',
#  '-zEynAwpLVI',
#  '_xYIJwAgJ_k',
#  'as-5cUQfhBk',
#  'ss4vpidhoHU',
#  'mXm-VjKPd1g',
#  'k-QBfI95DT8',
#  'z4fIO1-qF5Q',
#  'AD75Jds6EfI',
#  'mh9Mqqdvs9c',
#  '6t0tazaQy5U',
#  'r7X4ww16H68',
#  'D9_FvFWvSAw',
#  '3CGVbrCOrsA',
#  'vKaEjIPEGxc',
#  '3hFftuQdwSs',
#  '2Xh24NockS4',
#  'uhOjJIS5HIQ',
#  'wleEunjXJLk',
#  'OOCfxuEmSCk',
#  'cA-U338hrdI',
#  'rFGr1pg5_Uc',
#  'PLg5FgZjVyA',
#  '3aOXY3j8YNc',
#  'g9wXiIJxxEI',
#  'qocCXT_9cRk',
#  '1olMhbW9SOs',
#  'FjsCbmIZlXQ',
#  'juAF8d1-F78',
#  '9u_qRrwyEQI',
#  'RJ8A3mjuKL0',
#  '3c5hHUIHH54',
#  'NbJ55prgmFg',
#  '4ED_zduANt4',
#  'AfPjAWSGQg4',
#  '32gL5pW-_-k',
#  'BwXrq-IXqf0',
#  'sCZHENnY7zY',
#  'WIvbZUlxepE',
#  'tzIa2UaWB7I',
#  'FFMyN80W4a4',
#  'yaDmYd_S3sY',
#  'tTGYIEgne0k',
#  'f5ZdZRGLITI',
#  'gsnoEoyZ-q8',
#  '57oNWb4w3VU',
#  'upSADORbhYM',
#  'bqv7uphvjHU',
#  'J_CHunEwzOw',
#  '5SKwEBmpC5U',
#  'y6bLkHmZrQ8',
#  '3U_NRKIeN1Y',
#  'gmlvvur17qQ',
#  '3IpaFRIs4oo',
#  'y_gyCB_dRMo',
#  'Swr7QWKme70',
#  'Rnd5dY93Qz8',
#  '93VoZeEREwM',
#  'p1iLKSUQl7c',
#  'bTgfjK2f4wk',
#  'hXpd9BhNwS8',
#  'xDmrXFdN7bQ',
#  '1d_0ntaz6j0',
#  'IDA3tvXQTbs',
#  '1sT-mWQF5MA',
#  'ZDoZWorU5YA',
#  'ydHsLlarpDc',
#  'dVfv487Kx2k',
#  'Y4dGk8R2OJw',
#  'wo04Ft7rNf4',
#  'xiPKofKE1vg',
#  'V9q-egmwWO8',
#  '18K3eMFX0UQ',
#  'QNjmoOpsKI0',
#  'RvyXWBuTq78',
#  'g7IKEDSeOlc',
#  'lN8BIsMtpF4',
#  'WoGr30SxotQ',
#  'ucDjKyRYGrg',
#  '7fHTQv8h35s',
#  'MiY0kit0Q54',
#  'TNUrTntMOR4',
#  'zRdywsfPowU',
#  'xvaJyZUz5kU',
#  'arqEP86T4kY',
#  'qedMFDc8RiE',
#  'u4XeraUoy0o',
#  'AXf8V7BGcTk',
#  'vyNdxDJAGlE',
#  'QTmv2tm2rzs',
#  'ru5CSzUKISM',
#  'StkVy1VFNuI',
#  'JwKjneYoSsw',
#  'mwz3rMng1Hc',
#  'lL1Xebpm4yU',
#  '_nv3DgM7ipU',
#  'ld1eHFTR87k',
#  'RS60IHtnQTM',
#  'nmmVTsvr1mU',
#  '_K8aUftJPPs',
#  '-Yq6Oe63SUw',
#  'DHcO3jnGDXk',
#  'vZzEz5W9TZ0',
#  'ngIDoq6AwXA',
#  'N7vqIztpMqw',
#  'd_6C7Dq4rbE',
#  '65Ti4D_qxGU',
#  'zRMBPbHsQbc',
#  'Xsycym_Cb4M',
#  'TWPnIdMOyWM',
#  'E33rwNZLpu8',
#  'QWid9KyVLbk',
#  'DL0PNSOnFtQ',
#  'kmJU86g2ilg',
#  'pRTdN1cB_Yc',
#  'wW6wErwjsYc',
#  'a5CPMtVkeZ4',
#  'G0snaLva1-c',
#  'hSg65bbNsc4',
#  'GJ-F3UWOWr4',
#  'wsA82A_AN48',
#  'xuXWyi_P_MQ',
#  'jtNtRKigrC8',
#  'iPrmKZ0vuEw',
#  'jCQOtcW17Lw',
#  'SG3rNQRRhMM',
#  'dLoMcfl1Yvk',
#  'gaHTNiYyj8g',
#  'HkIwN7ffxX4',
#  'dsKGireGzzE',
#  'sdKQ2fqzzTc',
#  'jcFwyouLC7c',
#  '3pYJzfrjNok',
#  'vkp9-msqAfw',
#  'fBJ3tV9yVHc',
#  '8ec0Scm1IeQ',
#  'CvDuLF6dEn8',
#  'Fig96tiS-4k',
#  'ZUiywa4eAq4',
#  'Sp2i1BpmMIc',
#  'kQXt2rpukd0',
#  'rn_3nFKbbtI',
#  'U8sxk1FXkn8',
#  'O7UcgtW_qXY',
#  'cN4mvkJj8sY',
#  '-jthfYuO_98',
#  'PnqCJphMUdI',
#  'IkE_u7hWu1A',
#  'KcPpssiVDCI',
#  'J7D5RqxlCh4',
#  'QGX-H8sTG8g',
#  'NqDlM6vltjg',
#  'AtLchlrPjos',
#  'hAuUdp94uuE',
#  '3ATrmoZdLsE',
#  '2DfyKCpp5us',
#  'zQ482WjNtIU',
#  'jgbMVYzOQ34',
#  'XqO3zHUaldk',
#  'sEmIOH43jpI',
#  'hbHzdkBn8Lk',
#  'h3s44-3RE2A',
#  'ssJnswvPG1U',
#  '0c7D4jvIEQA',
#  'gONdfOAoTb0',
#  'bALA8aG0S-8',
#  'l_P1HlmqMcg',
#  'aDJrPMTiEts',
#  '1-VJYUsorpk',
#  'vyRSMZIvpkI',
#  'N_2i5fsn0bQ',
#  'BH6UuAD3_XY',
#  'XZrg07Bt0S4',
#  'DrUPIgutX1k',
#  'LwDURWOQEAw',
#  'DTKp56PlgAQ',
#  '_bnjg7cxSgg',
#  'S7em7qEvoT0',
#  'Krdwi0YCFdI',
#  '1YGFZFHZIQ4',
#  'GoFhl-W7VuA',
#  'RYh3a9k3BCY',
#  'QtTE6JiympM',
#  '59loWmMMyVw',
#  '0I5plxuLuZw',
#  'vhR_TJ_qII4',
#  'U3Q10sHKyIA',
#  'YsuLLVH3PWw',
#  '4Vuoqhs5i8M',
#  'URGtDRAu130',
#  'UoW72B0GlIM',
#  'J3Uo1WMytmE',
#  'vROr0Gr5yXM',
#  'o3BSGXWSpEM',
#  'xzFgCynNYR4',
#  'K8ilGJ6s1wc',
#  'rqWCNuSgdL0',
#  'zaCeRJsIsHk',
#  'ZiZKagGi9TE',
#  'o6cSwTdQ-5k',
#  'q-HrAIWXR60',
#  'Ep7VpKGsrYY',
#  'XxyfaxcsMp0',
#  'hiVf_Hzieu0',
#  'iVB0EBFgo08',
#  'mHZTHbzGv68',
#  '030FyhP9dbw',
#  'oYQpgyOggFQ',
#  'OC571n-eJD0',
#  'aXuqDESRu6M',
#  'IlxXcmo0dVM',
#  '9vzu9WdpdN4',
#  'scJ9mYK6Yqs',
#  'tiwLnhx16rs',
#  'VSYWbx2gxEk',
#  '_XLkP_gaaQM',
#  'cFzDdySWd7g',
#  '8qr8Jkkm60g',
#  'oWMwZZ5S3Ms',
#  'KfmFd8f0Icc',
#  'WHtNvcfHmy0',
#  'tBGT35-ESDA',
#  '2H1jmPwbHgg',
#  'vVoxEbQnejY',
#  'IZqqNzn8owo',
#  'JnwWKPRQ4Ss',
#  'S593IC3wNdU',
#  'SbuJq8wfe7I',
#  'EL4x56x32xs',
#  '3DhE5GvyVeo',
#  'YbZcrcobkO8',
#  '_INX5cPEDPE',
#  'YvPyGvxzSHc',
#  'MPN1-pCVuUQ',
#  '7mvUhK5F4co',
#  'T9S2V66K45g',
#  'c8wQ314XIhk',
#  'V15vBcQTHik',
#  'Fwc1jfIAKYk',
#  'JxF-vK62rJk',
#  'D-MjJttaOoo',
#  'g4r_Cv1IaHw',
#  'qsjUcCamMoM',
#  'R1gROoDgPs4',
#  'FIQxam695EU',
#  'OiPGsjT9QKA',
#  'DsQm1kb3ui4',
#  'AfZyyH0KA80',
#  '_rucfHnryyE',
#  'BfZUKrX8OFw',
#  'ISwghahgI24',
#  'RcnDJrDCoeU',
#  'H6hKGmaUPv0',
#  'mAUtJOda1HY',
#  'sRN-6vPXj1U',
#  'vGpUKCSYm4s',
#  'K03JZKa1zXk',
#  'o_T-m7_qVu4',
#  'FBYgBBRny3I',
#  'G0Pu6K7GHEY',
#  'miHXYEtjvf0',
#  'wITCLdPOfqg',
#  'zHFRIWIgqTw',
#  'eW9h81EqpHU',
#  'qBdvoWUrVWM',
#  't-vNKX8LMjA',
#  'orH9vQy9BTQ',
#  'nT2nacrM0hA',
#  '7Y_n4r_J5Zg',
#  '79MoV_vWZzU',
#  'r18N63XtbeE',
#  'rUoYRoS7QUQ',
#  'OsKjTYWFHj4',
#  'LsVd1AQIlDQ',
#  'CvnrL0MwY4g',
#  'V4ECa36lVrE',
#  '9VTYvYkrNKg',
#  '-SpYAqmv228',
#  'xKdf-EJ2iFo',
#  'v-tgm58Tpww',
#  'YbBCNcdlNc4',
#  '4STJmJdFu2Q',
#  '8mX97wMYrhw',
#  'pUxXzHw7g0U',
#  'KFvRKYdp8y8',
#  'qHAbyjH7_Zc',
#  'dvlMFLBITTU',
#  'jQ1_zT2tiqU',
#  'T_Aijvny-4o',
#  'rxVeb1fEz-c',
#  'pWqM-qolpX0',
#  'fB7R10mFGoQ',
#  'ahN426_Uw-g',
#  'kUnKwbTauyQ',
#  'gQS0k0kg3wU',
#  'llrh5zlgbLk',
#  'z2bSqs-ORDI',
#  'TPGEif0F8Z4',
#  'vTxQ_DpTTgM',
#  'KXxRsgM5azY',
#  'xl7PRN1Yhwc',
#  'HnypRPC49nw',
#  'SzYrIGiwX1k',
#  'b0fJwzhLufk',
#  'Bqdke7EyFxw',
#  'NHfIMbB2mtQ',
#  '_JXJtkdsIPA',
#  '-1qzPq3tI-8',
#  'Zm2BEbKgNsk',
#  'w1RewWCmS_Y',
#  'NWchMtixrMU',
#  'maITxdoMI8s',
#  'sDfq7eCQKvI',
#  'O6SPa9foUxY',
#  'j6OYEaeJyoI',
#  'PAeylAQb0sE',
#  '4Khna9hEh8Y',
#  'wktj_amXbXU',
#  'glXZaMJXw7Q',
#  'qkgOVtnBebA',
#  'FGbgA9ZVjLk',
#  'CHvZ2DpwpEU',
#  '8R-gkC-Kd6s',
#  '7qwkVInOPTs',
#  'Uv4tvU69brg',
#  '6YLChD1DVfI',
#  'n6zkBwfU_JU',
#  'lD6XXS2Cvyg',
#  'PPmOxvT92L0',
#  'To72aNKp2X4',
#  '8BTHciR1JK4',
#  'NaJH6ojJ9TE',
#  'wfQJdf_Uq1o',
#  'BEOQxFKzboc',
#  '252rP2RIFYs',
#  'xlFcq65IWnE',
#  'TL8KZe8MU2c',
#  'sO7axRN0uMY',
#  'fG3Xz5PiG6k',
#  'kDzTrJFJLDc',
#  'DxBgQGL7k6I',
#  'hY7Gixxj84Q',
#  'owwdqgB26gk',
#  'DNArjJMeFn4',
#  '_mEvOsvJXSg',
#  'TnG07mXxckQ',
#  'xVGmPeB4HZQ',
#  'Y6azkdQUGa8',
#  'hb1RkHXSe3E',
#  'Cws3Pw0Q-pE',
#  '_RvvdQIJYfc',
#  'TM1VaDE4goc',
#  'p_m93kbqtpE',
#  'iAP57mOxSfc',
#  'A-HCQMWSQLE',
#  'zjaRwcChiI8',
#  'C62wTqPa8CM',
#  'Xx6z40EHXQs',
#  'aDj9HSuVBYM',
#  'NPBPdHZnhjI',
#  'e_DbFw9yB28',
#  'CUdNZoaA6yc',
#  '5H39ejIt-cc',
#  '4FiOgA0HzeQ',
#  'NWIlctMkzIk',
#  '-zqZ1chZUEE',
#  'JL_fSDkmwUQ',
#  '2thsBwZBN0I',
#  'LsSHgsT6AJg',
#  'aHVrQ4NbfUE',
#  'K0_TJmxJsmM',
#  'aTLKgx7h2Lw',
#  '_SD2brw4pzE',
#  'vkSidW8YOsA',
#  'qH0e9nyRiMg',
#  'AbDSqZFDx8g',
#  'cLRWzuFdCVw',
#  'mBjWPK-5k7s',
#  'qceivT1NEAY',
#  'ZWs0yB433WE',
#  'jcbl50K-6Z0',
#  'A_er9nfY110',
#  '3UfkqZVTeyY',
#  'xq1FjiAYJl0',
#  'BfPkQq7Sas8',
#  'f5q3yIPb1-M',
#  '_rvSawmyyNM',
#  'r1MuVc39Xh8',
#  'Wc8W16yAPbU',
#  'M11sklVM5po',
#  'gpFLj3TjqUM',
#  'xMyGR9Bn0HI',
#  'lchRgZ-Q9sY',
#  'VuJMViIHu3M',
#  'xoha9y7QH7s',
#  'kJdYuE42K1c',
#  'peeg_ZmgtTw',
#  '2dPDFcvVZy0',
#  'tbJH3clolCY',
#  '_x1K_CStw1s',
#  'jla7V9uP0F4',
#  'ftO3le8uDgQ',
#  'CATgFeV1V4c',
#  'o24tnbwmzTA',
#  'ngi4JdJjsdA',
#  'X3KEV4MrptE',
#  '9NqkaidS_XY',
#  'E5_hwh7E6q8',
#  'Dbve66dNhwA',
#  'td16kTzD2W8',
#  'DJad_Tz31O4',
#  'm-UPdXRN314',
#  'EponyzAeY7c',
#  '0Jk4l6xfGrM',
#  'WVl6cv2yD9s',
#  '3TXUTguvE4Q',
#  '00Ji0PtcKI8',
#  'VcM40zwD6xQ',
#  'pivkHRNy9d4',
#  'eDYgcOiqlhg',
#  'eUWHoNBer5Q',
#  '30VXB_yMZRg',
#  'vkKmtXNd4v4',
#  '_phRL9VUEzA',
#  'pHJOTf6h6dk',
#  'cKQWI2hoZAc',
#  'RwU54AJX3Io',
#  'cNrsM8HwBKQ',
#  'NzQgTwJ0X-0',
#  '_i9hQ2zYohg',
#  'Y5AaKRlkcaw',
#  'H8EQQujSOsA',
#  'wGN8xwWiXvo',
#  'FPrgRzd4-H0',
#  'vvD5aVHEtX8',
#  '928eE4KyB2A',
#  'uUtE3RlBmzg',
#  'oLPKvgkYH0M',
#  'ztZSJ9F99NE',
#  'J8KNo6ypH6A',
#  'eGldRqvfP0g',
#  'uLGDsHJFlDU',
#  'F8tw0l37x5k',
#  'Gh3KLODoYgE',
#  'vXgqICf_y9I',
#  'Xe4q5BmGalo',
#  'Ceu3s9gaD0I',
#  'm6eud8rGzco',
#  'lPWOkeKN7kA',
#  'mYbAroX-JXQ',
#  'IIjgFfkmaT8',
#  'pWvKFXwmfrk',
#  'F2Q2-xmtgUA',
#  'kvrN9KLbeQ0',
#  '61sb8zpcOTU',
#  'YU2_z0UzvVU',
#  'pv7l2Cxe5ok',
#  'Uj9_C9R9toQ',
#  'JxA_0zecPYA',
#  'RU0Z48QUgDs',
#  'kBCYLKFZme4',
#  'tAQunw2PMi4',
#  'ycN8IE_cgG0',
#  'x54VhIB9EN8',
#  'DcfMTIfP7t0',
#  'fGIFVme6y-U',
#  'DCctZiuspmU',
#  'hw62_NNj3ZY',
#  'Imln_D63RTQ',
#  'AfXaJHaAbT0',
#  'MBF5fr_yOBY',
#  'o0IUZY5wPLY',
#  'YpikBQQpAUY',
#  'oJpFrjwT-MI',
#  'ShS1IH3csnM',
#  '_SMkDYW60mM',
#  'oJLkYHUT-Cg',
#  'whSq_kgMPGg',
#  'NPca1mfMnUc',
#  'wh09kf1-krA',
#  'n7PV_4au3LM',
#  '34qyqoc01xU',
#  '5J5BMif9UBg',
#  'eAD1cOJgFhE',
#  'gFbJXiV6lL0',
#  'fHz_JPBwiIo',
#  '2SgD22GXY_A',
#  'UiI4zYjcqhA',
#  'Zkl3pxtQ--c',
#  'Fq9OtrzBw9U',
#  'cj-9lhidla4',
#  'b8mlh-bARvs',
#  '35rUwebLolM',
#  'Tsq3Wkmkq8E',
#  'o1CNtDedPWw',
#  '2A3QMOV2SeY',
#  'ySzmJf6G4qo',
#  'uzZmvSLj_n0',
#  'N9pZXzzd3tg',
#  'e9d8VZr2neU',
#  '3tbGMt6HFlc',
#  'xSXgyUC82MY',
#  'PAjArUkazHA',
#  'kpYFDgPkbNo',
#  'kVKvTkc3_XA',
#  'coO5fFGhBNk',
#  '4selha9yLgo',
#  'lh2kFiGo-_U',
#  'mORIJySMK_I',
#  'E2cl3fK0gXY',
#  'cmUvffv9SLE',
#  '6U0I-cretEM',
#  'LVa2naEgKLE',
#  'PjeBDUccojo',
#  'c2l9vD-apss',
#  'CV4sKDytwo0',
#  'OTjU22MdvUE',
#  'aXPQnGQ4sZU',
#  '5wfA0z8M0Zk',
#  'Det9DXgXDRE',
#  '57SzDY5slTk',
#  'Kvc-QCcLkro',
#  'UywrXBDrlM4',
#  'LdApqMBtUt8',
#  'rYIxYnWzJ_I',
#  'f2R2HzXT6P4',
#  '06vCWYalK24',
#  'DSiD2WTcvBg',
#  'jNSotOarJ-0',
#  'J9EnPrCZNPQ',
#  'Icj4Fs8uCfQ',
#  'NJ-bbglbOLk',
#  '_xziy85zgp8',
#  'N0gNAp6czAM',
#  'SQrvZ2FVHEs',
#  'Q-okkA_iDbU',
#  'vilFuOUQ1fQ',
#  'armdaYTowoA',
#  'jfv7hIQQNyU',
#  'JwXwUR8HTz8',
#  'RHpOu4co5W0',
#  'medHTraY19o',
#  '2jqpeqs50EQ',
#  '7x8Qs90JMDg',
#  'Ldyp1PZOcS4',
#  'Fj3pukXNNdk',
#  'sxAgVs08v-U',
#  'grgKLwRWXPA',
#  'PMJAiIiGMvk',
#  '63zRSTkb8Qc',
#  'lVzLONulMoc',
#  'b3gHC5WU7rg',
#  '-tdj3Zb-jvg',
#  'uZ4x32DvYOs',
#  'TqxKHk07p5A',
#  'BNvvI5F-JFM',
#  '_34qWM-J-Ho',
#  'kTWs8a-MXWQ',
#  'yl43pmh6lAE',
#  'KrIqjq10B6s',
#  '0K_RlqRxnls',
#  'wRfkwFu1coM',
#  'Haz9BCyE5_0',
#  'G5mbyiJ96ak',
#  'G9d2b76wtsw',
#  'lCmXWOjw1QQ',
#  'AF-w1cEFUhA',
#  '0dCynSFTVR0',
#  'O_ssXqBm8J0',
#  'GeL-Bk2Gyrg',
#  'GZtrErBg2_k',
#  'RWZ-DSWDl5w',
#  'GrjwtXeXEUg',
#  'ZR7oNuD2Bwg',
#  'K75kJ09QkxI',
#  'd_gq85s14Rk',
#  'yCudV212ohI',
#  'zi8pmY0BwFE',
#  'nQv1D1mHVt8',
#  'B8deFW4z-xk',
#  'hB6Q6yIeuGQ',
#  'N5D73_MF1XA',
#  'VItTrUOaGKs',
#  '8Ip9BmGVmRw',
#  'VdWzSZDuN6g',
#  'EUqj638oySg',
#  'ertHRKolH4I',
#  'DsG4xZpqznc',
#  'JYfkx6SidRs',
#  'HdYnHUtXZu4',
#  'jKAColf24XY',
#  'IcwuZEkThCs',
#  'ycBHsYIsd4E',
#  'y6-MKIhqsj0',
#  'wR-P8fdwguo',
#  'XAofRbqxwBw',
#  'otePKZkKlxQ',
#  'C-OHlNvGUEw',
#  'xkUfB-itlMw',
#  'dqYh1DUNlgA',
#  '1EYuiWkGMXg',
#  'DBfx6VgLSVQ',
#  '9sBgseTrj1Q',
#  '5F6oDMnZAS8',
#  'z2b0l-2t1gg',
#  '5g7CtZoo5GU',
#  'oUGea_dz4Hc',
#  'dP-cS89nHr4',
#  'kFCy24AU7Bc',
#  '0Xcd7NSFBBM',
#  'OA68xEjzonM',
#  '1lUYZ38pE_s',
#  'nM6Se_EIQbo',
#  'aVADCiIpdnc',
#  '_ELKyeVNW7A',
#  'ODQpEZ5nZVI',
#  '6AO54rb1MwI',
#  'kcXEY3_w2EA',
#  'spQvEjl270w',
#  'LS1hyN53WEg',
#  'BrKbvYR1WP8',
#  'zo2JRSfwCT4',
#  'iCocZyxLYzk',
#  'mx5K0ERLPAE',
#  'GYvAxJGnGOc',
#  'pSppf8efJf4',
#  '6RE8wpwtEcQ',
#  'JUPFWB4k-Eo',
#  'LpdKUbPs8Yg',
#  'lVUhTQFUG14',
#  'Hq7gpV5JWC0',
#  'pIzFQMtrdMI',
#  'oUaIX4uKfPE',
#  '0hRQC9E68bo',
#  'qPDD_yLWUbU',
#  'p8L1W4w8GzU',
#  '4ST5aNUJBYs',
#  '8zFE0e3XmSY',
#  'mt_pNEgux44',
#  'bbBpnV984OU',
#  'x0-SXnXSjJw',
#  'sqYugFma4-A',
#  'NyV9jGa_HSE',
#  'jOSdmRWXHD0',
#  '1oMG7G58Jnw',
#  'T2Vr0ldNBqg',
#  '6eu6FAnOZbM',
#  'ACI_jNzKZCc',
#  '1cRJGFKsj6M',
#  'SBro07KZC0o',
#  'dcvdPgqB_yw',
#  'gGPAjWkDQ54',
#  'dKZiNE4CaIA',
#  'ktpyDomFF0k',
#  'n1WncZguKRQ',
#  'YhSq0PbAgZM',
#  'bckHEDGR9qg',
#  '9mUm2TFGLfI',
#  'uEIVAeleaN8',
#  'JPwrp8I5N2c',
#  'jx-JPEj1tG4',
#  'uZSxKcXyssM',
#  'FE8r8_sJms4',
#  'iJQaF5PN_0M',
#  'knjrPkWXSik',
#  'fx1pY4qOga8',
#  'n4ZsX5RFfWs',
#  '3bU0StMbMqE',
#  'AWJRlfxcq7M',
#  'dwue770pyfQ',
#  'aBqZhNOs4O8',
#  'dhryEGid0jo',
#  'E-MucVpJodo',
#  '6F9zZ_Widp4',
#  'MbICypw711g',
#  'rlqpwTObQuE',
#  'NS8Gus5XEk0',
#  'cYXbjsIsNNo',
#  'jYgkvHIkvN8',
#  'Gy_hiPvBvEY',
#  '49pPBzu7tBc',
#  'fG_z1-0UVSg',
#  'OhsajCzOyGQ',
#  'ebzE3f9ByT8',
#  '6asIaxMHqOA',
#  'gMDmngMPXXo',
#  '-LhVmJIZCl0',
#  'rNh16Nq1mlg',
#  'lK5214fV3IE',
#  'AmNOnsBzjYw',
#  'I7RSbgRlixc',
#  'X_d9TiOJa0w',
#  'bvd1Ba6HbwY',
#  'n6Za66zMvyA',
#  '6qO7IUrhWHw',
#  'gh1Etl_TjeM',
#  'JO6BVOpp0PA',
#  'UA6AOGRh3n4',
#  'yY2-Su1rWeU',
#  'GQo8AWE_TgM',
#  'mtuwriwbK9U',
#  'kz7VZNBWM68',
#  'VxtPhDY9om0',
#  'OBPe0xzaL20',
#  'ISW0n8VMaZg',
#  'UtV07E_Yynk',
#  'HfCY02mT-TU',
#  'XtMkYVpX3R0',
#  'ioCBzpVyor8',
#  'uah6sPmfYEA',
#  'lPaECjmv9VA',
#  'f6QsgAmTdIY',
#  'efd3Y6sC97c',
#  'NagFZNf1_TY',
#  'wsNIWZF_yRs',
#  'RjKg7uGeMs4',
#  'gXvTItAZRug',
#  'm6pwyqxqZxs',
#  'zNMT_IV6XBk',
#  'yXrSVcl5Vl0',
#  'KYfEEHN_IDk',
#  'J2uO_vpMjvE',
#  'HopBgmT2a8M',
#  '4hKJoxbjFBA',
#  'eW_0EaKTq6E',
#  'ZvvknIbYmgc',
#  'EodHKf5FGvQ',
#  'KLjmeUANIS8',
#  '6C3FBgm1TPo',
#  'SSQ05g6VOTw',
#  '_6ZdYQInHB4',
#  'LuVz9vg4F88',
#  '3ZewkeS9f0Q',
#  'x8uaXCPL1gI',
#  'JNrJz7yLo1o',
#  '8uDpGLsoPE4',
#  'pKNBPkKprw4',
#  'JPglPUv_WKI',
#  'NvXhJkSAE0w',
#  'i4-nB6wacVI',
#  'vpkDMmZ_wN0',
#  'UTMHExrFMiw',
#  'KgdLyA5978U',
#  'ct9VddcCg5Y',
#  'zC_otaB_-cw',
#  'aiWdCEaAzYY',
#  'GiWTaCMILAk',
#  'VuMTo2E9FhQ',
#  'wTMlnIjxOnY',
#  'W7jBdDsDoOE',
#  'HIEsb9xTXkg',
#  'Jen9XnbaywM',
#  'Gi3JlTXvV1w',
#  'FUnny_ucc3c',
#  'nh1BdWMp9Qk',
#  '4aE5cYR2XVE',
#  'G5mAbQ6_4qY',
#  '_BBjJn_FB5I',
#  'e8wOZDLB_FM',
#  'KNdtun0w_AM',
#  'i1Jpl1PCprY',
#  'OBk-e3WZE6I',
#  'TL1l1J-gtgY',
#  'gXq0OwKFcSs',
#  '9EGeEX2KQDI',
#  'hVBLWPxw1_c',
#  '7RcdEY24pXQ',
#  'm_EijJL10j4',
#  'aiCFrB6cAio',
#  'qeQW5TJCytU',
#  'eMZKzQpjeu4',
#  'HZtcqMFOmCY',
#  'GLUcPJhG4c4',
#  '8s3k_0pvvMk',
#  'MuJhV-6zR8k',
#  'sgD3X2gVP1A',
#  '0nnxrR5dmio',
#  'F30pb26qx6Q',
#  '6rYdOYEKoe4',
#  'yEfi9WMTb_E',
#  'YZ5Evrb0DAc',
#  'vH2Ra_9rhC0',
#  'Z-aemXg_t00',
#  '_23HFoWrwM8',
#  'RIJR_nnVvEM',
#  'E52PGrLJqkM',
#  '0FFyjCaiLJs',
#  'y5B7V4Pd6mc',
#  'd_rPqzNt38g',
#  'zzCeYnus5_o',
#  '7__DWFQXwsw',
#  '0Abdw_RLoU4',
#  'A8kRSSMWe-w',
#  'QdtAPZUnh4E',
#  'ZmGNBSUwXyc',
#  'NuZY-3J6W5c',
#  'NXxbui-kqzA',
#  'bn_lQAP8td0',
#  'sE5lPpwlOmU',
#  'C8K-eIZ1Ahc',
#  'FmtR2qFtIsQ',
#  '7OEMQLp9Vxg',
#  'QHipMF8fJ5I',
#  'iQ66QoSlZVg',
#  'XY__DVwdmSQ',
#  'RHurZFPciTI',
#  'cJjLoOXGu2g',
#  '6brXRJW3GGE',
#  'ut7UgnxTvr4',
#  'z_OZwUfsQCE',
#  'hodO0_KYq4A',
#  'aqHQj27bkOk',
#  'VF3QYtwR21A',
#  'sBqUKfi4ng4',
#  'qDKbvB-Ikfs',
#  'NAxvQrjQizE',
#  'dVc2yLg68i0',
#  'GI2UvkgXDOI',
#  'llGpprWm_Nw',
#  'DnQYqJ_5PyU',
#  '6L0b8VdkBn4',
#  '0HjJd-C9Q1o',
#  'CrE5WtUAoBU',
#  '8BO94EG3-ds',
#  'rasEHAMqjPI',
#  'g9DzAjIcyfo',
#  'MOyYqJ0jjF0',
#  'K1TapZ0h89A',
#  'k5LqOT1ODPo',
#  'Y4THbj-oktc',
#  'oFfQAQKGV7w',
#  'j0HXAg5ytUU',
#  '8epz9cas7os',
#  'ycugqP3Skmk',
#  'DPZ4hBFxg24',
#  'k9cBK8MaD1g',
#  'Q-TH9pRidlM',
#  'yfa-7jg3SIc',
#  'Ea4-v54tRuA',
#  'hgd16QPp5Bo',
#  'iAXz27gFtvo',
#  'O_DmHd9MlCw',
#  'dx46C_2fg9U',
#  'uK7WSPqWh_U',
#  '2StTCEZzlO8',
#  'hDXTRqj0XHI',
#  'kuAjXYQFqTA',
#  'z1O28g8mFNk',
#  'ei18M9U3thY',
#  'NWmj1s_HXdo',
#  'IX0z0-jqXbg',
#  'x3pf0HBafhw',
#  '3dWGBY7oPnc',
#  '33lD-gdy_bw',
#  '7fFs3Gs0-6U',
#  '7vSl0AdUL3k',
#  'vaPTxZA1ALc',
#  'CBCx93r7Rro',
#  'sId099wuYHU',
#  'ghMI_2ImLi8',
#  'VB488AobgWc',
#  'dTDLjeaJsEs',
#  'k2PK74bccXQ',
#  '23wWJCgdkWs',
#  'a39f4JDHYAs',
#  'wRkIpEm1ZrY',
#  'UiwTxi1lg9Y',
#  'dzAU6XuOL8k',
#  'F4NiFfv2MYw',
#  '-OhLyrgZy50',
#  'zfyDQ_IcU3g',
#  '3gNU9mIxiok',
#  'K7_zYVgaZ3w',
#  'v2DXHyGJuao',
#  '5NnI2BsiU2g',
#  'dx4pwt0HmnE',
#  'omHcqId4wk8',
#  'PQOqSoX-Otk',
#  'Jx_I1zyGdwQ',
#  'OuhgAAOFAm4',
#  'z3Lw8mca6Gc',
#  'GkLMbkZSNmA',
#  'Yn6P2JH-CqY',
#  'yjvaV-08alU',
#  'HkqL0n4SxGY',
#  'iu1FSBl5uWw',
#  'ValoXnlnR2s',
#  '-adUhxh8qwg',
#  'T48T5FLfq7M',
#  'Jqqcr57v1RQ',
#  '0LyAtyGRy2s',
#  'AMgchX-vpMQ',
#  'Zrgz85_vFrE',
#  'kqdeyegtNpo',
#  'XHPt-VSyaHQ',
#  'kaQd3sBsUVQ',
#  '1cMUbGPEq24',
#  '5enG0bNi8wI',
#  '8c-ozwqt_1g',
#  '2UNjb0t1z6U',
#  'zrEhoeCYq-I',
#  'bvYGceFGiy4',
#  'XtQrUSSxT5A',
#  'O6-0WGh8Mug',
#  '1Z2YZS-KlUo',
#  'p232zxt6yTo',
#  '_gjWNgtnzxY',
#  'IwpUD8vyjo4',
#  'PVRCR0FqJow',
#  ...]

# %%
len(Video_Ids)
# Out:
# 1157

# %%
# Get Video Information

def get_video_info(video_ids):

    video_data=[]

    for video_id in video_ids:
            request=youtube.videos().list(
                part="snippet,ContentDetails,statistics",
                id=video_id
            )
            response=request.execute()

            for item in response["items"]:
                
                data = dict(
                    channel_Name=item['snippet']['channelTitle'],
                    channelId=item["snippet"]["channelId"],
                    Video_id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item['snippet'].get('tags'),
                    Thumnail=item['snippet']['thumbnails']['default']['url'],
                    Description=item['snippet'].get('description'),
                    Published_Date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=item['statistics'].get('viewCount'),
                    Likes=item['statistics'].get('likeCount'),
                        Comments=item['statistics'].get('commentCount'),
                        Favourite_count=item['statistics']['favoriteCount'],
                        Definition=item['contentDetails']['definition'],
                        Caption_status=item['contentDetails']['caption']
                        )
                video_data.append(data)
    return video_data

# %%
video_details=get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'KJsCG-Ho8OU',
#   'Title': 'Superfans! Come join us for the #WhistleParakkattum superfan experience on Feb 8, 2024! 🥳🔥',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/KJsCG-Ho8OU/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-02-06T08:54:47Z',
#   'Duration': 'PT21S',
#   'Views': '21205',
#   'Likes': '2210',
#   'Comments': '17',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'wXvNBd0J_a8',
#   'Title': 'QR-ius are you? 🧐Scan and see for yourself! 🥳🤩🔗 #WhistleParakkattum',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/wXvNBd0J_a8/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-02-04T10:02:46Z',
#   'Duration': 'PT8S',
#   'Views': '16731',
#   'Likes': '1622',
#   'Comments': '7',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'Rzvw1q7l2FA',
#   'Title': 'Auctions, Golf Plans and much more | Kiwis On Call ft. Rachin, Darryl, Santner, Conway',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/Rzvw1q7l2FA/default.jpg',
#   'Description': 'Experience the virtual camaraderie! Join the four Kiwi sensations of Chennai Super Kings in an entertaining video call where they share laughs, stories, and excitement for the upcoming season.💛',
#   'Published_Date': '2024-01-28T13:34:28Z',
#   'Duration': 'PT9M16S',
#   'Views': '111953',
#   'Likes': '5262',
#   'Comments': '175',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '9W4FqLKy4Gk',
#   'Title': 'Junior Super Kings 2023- 24 Grand Finale LIVE | Jepiaar School vs Ramakrishna MHSS',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/9W4FqLKy4Gk/default.jpg',
#   'Description': 'The big stage is set for the Junior Singams! Watch the grand finale action LIVE! \n\n#TheRoarStartsHere',
#   'Published_Date': '2024-01-26T18:12:26Z',
#   'Duration': 'PT5H6M42S',
#   'Views': '57307',
#   'Likes': '3169',
#   'Comments': '25',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'vBCbzWmXpcA',
#   'Title': 'Back In Yellove ft. Shardul Thakur',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/vBCbzWmXpcA/default.jpg',
#   'Description': 'Rewinding the memories of Dhool, our very own Singam with the golden arm! 💪🏻\n\n#WhistlePodu #Yellove',
#   'Published_Date': '2023-12-23T12:57:06Z',
#   'Duration': 'PT4M17S',
#   'Views': '89567',
#   'Likes': '6374',
#   'Comments': '186',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '5UpeKysSTS4',
#   'Title': 'The beginning of the roar - A Catch Up with Sameer Rizvi!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/5UpeKysSTS4/default.jpg',
#   'Description': 'It’s the beginning of Rizvi’s Yellove story and here’s him narrating it! Watch and whistle! 🥳📹',
#   'Published_Date': '2023-12-22T16:00:31Z',
#   'Duration': 'PT6M17S',
#   'Views': '97683',
#   'Likes': '4835',
#   'Comments': '152',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '-FzGywV6bl8',
#   'Title': 'Very Excited to join the #Superfam!” 🫂💛 Mustafizur 🎙️ got all of us eager for the summer already! 🔥🔜',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/-FzGywV6bl8/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-22T13:04:59Z',
#   'Duration': 'PT12S',
#   'Views': '383843',
#   'Likes': '33828',
#   'Comments': '478',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '38hCJ9W5hB0',
#   'Title': "Listening to the fans' IPL auction 2024 R̶e̶v̶i̶e̶w̶ feelings  💛🫶🏼🤩",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/38hCJ9W5hB0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-22T10:04:28Z',
#   'Duration': 'PT52S',
#   'Views': '86553',
#   'Likes': '8249',
#   'Comments': '38',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'u5SGrSWwx7s',
#   'Title': 'Lion-ed Up and roaring to go!🦁🔥',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/u5SGrSWwx7s/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-22T06:23:14Z',
#   'Duration': 'PT36S',
#   'Views': '88592',
#   'Likes': '9147',
#   'Comments': '26',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'lGgMw1Cniq4',
#   'Title': 'Yellove Dubai Ah? - IPL 2024 Auction Dubai Superfans Showreel',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/lGgMw1Cniq4/default.jpg',
#   'Description': "It was #Yellove with our Superfans from UAE! Here's their auction experience as it happened! \n\nIf you are a Superfan as well, head over to www.chennaisuperkings.com and become a part of the pride kingdom!",
#   'Published_Date': '2023-12-21T14:07:13Z',
#   'Duration': 'PT2M55S',
#   'Views': '31584',
#   'Likes': '1964',
#   'Comments': '83',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'ne9u_8R8F-E',
#   'Title': 'Post Auction Review - IPL 2024 Auction ft. Kasi Viswanathan Sir',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/ne9u_8R8F-E/default.jpg',
#   'Description': "Here is the post-auction analysis of Kasi Sir! 🏏 Join us as he reviews the bids, buys, and the exciting moves made during yesterday's IPL 2024 auction. Get a firsthand look at the strategies that went behind the selections and the team's outlook for the upcoming season.",
#   'Published_Date': '2023-12-20T13:08:18Z',
#   'Duration': 'PT1M42S',
#   'Views': '135123',
#   'Likes': '7890',
#   'Comments': '233',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'JP5_oh60rVE',
#   'Title': 'Excited for what the future holds! 🤞🏽💛🦁',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/JP5_oh60rVE/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-20T11:45:57Z',
#   'Duration': 'PT11S',
#   'Views': '51530',
#   'Likes': '6700',
#   'Comments': '36',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'MQgYm4gm1V4',
#   'Title': 'Glimpse of the great memories with the super fans ⏪🦁💛#IPLAuction2024 #YelloveDubaiAh',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/MQgYm4gm1V4/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-20T05:35:21Z',
#   'Duration': 'PT29S',
#   'Views': '43161',
#   'Likes': '5021',
#   'Comments': '18',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'xnEdfZo-2PI',
#   'Title': 'Coming 🔜 to Anbuden 🫶🏼🥳Message from Sameer! 🦁📹',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/xnEdfZo-2PI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T15:19:33Z',
#   'Duration': 'PT40S',
#   'Views': '114173',
#   'Likes': '14560',
#   'Comments': '114',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'DhvBzXWwR1w',
#   'Title': 'Rizvi Intro.mp4 📹📂',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/DhvBzXWwR1w/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T14:58:14Z',
#   'Duration': 'PT37S',
#   'Views': '172046',
#   'Likes': '18048',
#   'Comments': '100',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'zAyvCEowEnk',
#   'Title': 'Mellow welcome from the Yellove Army at the Superfan Zone!  🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/zAyvCEowEnk/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T12:59:43Z',
#   'Duration': 'PT34S',
#   'Views': '79109',
#   'Likes': '8893',
#   'Comments': '38',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'vjDoOlWBJp0',
#   'Title': 'And the journey begins yet again 🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/vjDoOlWBJp0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T11:51:24Z',
#   'Duration': 'PT56S',
#   'Views': '144449',
#   'Likes': '23469',
#   'Comments': '225',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'MRe9L6HxRvo',
#   'Title': 'DM your yellove for Daryl Mitchell 🤩🦁🥳',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/MRe9L6HxRvo/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T11:20:22Z',
#   'Duration': 'PT28S',
#   'Views': '162292',
#   'Likes': '25819',
#   'Comments': '283',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'bwy8VYlROvc',
#   'Title': "Superfans Mindvoice! 🥳🎙️ What's your take, Makkale? ⬇️",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/bwy8VYlROvc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T10:59:54Z',
#   'Duration': 'PT55S',
#   'Views': '60496',
#   'Likes': '5211',
#   'Comments': '15',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '0bmEvVq7Ws8',
#   'Title': 'First Time in #Yellove !🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/0bmEvVq7Ws8/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T10:34:18Z',
#   'Duration': 'PT59S',
#   'Views': '169032',
#   'Likes': '26178',
#   'Comments': '289',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '6ddd1yXsWK0',
#   'Title': 'IPL Auction 2024 Preview ft. Kasi Sir and Stephen Fleming',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/6ddd1yXsWK0/default.jpg',
#   'Description': "Get an exclusive sneak peek into the game plan, strategies, and many more in this IPL auction 2024 preview. Don't miss the excitement as we gear up for the next chapter! \n#WhistlePodu #iplauction2024",
#   'Published_Date': '2023-12-19T06:00:05Z',
#   'Duration': 'PT8M19S',
#   'Views': '91915',
#   'Likes': '5627',
#   'Comments': '272',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'wJNX3ZlaUkQ',
#   'Title': 'Anbuden to Dubai - Voice of the fans',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/wJNX3ZlaUkQ/default.jpg',
#   'Description': 'Join the excitement from Dubai to Den as our superfans reveal their top picks for the 2024 IPL auction! Be part of the anticipation and share your favorites in the upcoming auction by commenting below. 🌍🏏 #iplauction2024',
#   'Published_Date': '2023-12-18T17:12:53Z',
#   'Duration': 'PT1M47S',
#   'Views': '26949',
#   'Likes': '2604',
#   'Comments': '201',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'YwSJggqfPGs',
#   'Title': 'Reliving the final night and more - Lions Up Close Ft. Rayudu',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/YwSJggqfPGs/default.jpg',
#   'Description': 'Dive into the heart-pounding emotions of Ambati Rayudu as he recounts his unforgettable moments from the IPL 2023 finals. From nerve-wracking highs to triumphant elation, join Rayudu in reliving the intense emotions that defined this championship clash.',
#   'Published_Date': '2023-12-17T14:51:00Z',
#   'Duration': 'PT4M11S',
#   'Views': '35401',
#   'Likes': '2734',
#   'Comments': '108',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'Ri5Gnml8jNc',
#   'Title': 'Reeling back to the summer of Yellove - Lions Up Close ft. Rahane',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/Ri5Gnml8jNc/default.jpg',
#   'Description': "From the thrill of IPL to the finesse of Vijay Hazare, witness the captivating journey of Ajinkya Rahane! Don't miss out on the excitement - hit play now! #WhistlePodu #yellove",
#   'Published_Date': '2023-12-09T15:07:50Z',
#   'Duration': 'PT8M8S',
#   'Views': '72770',
#   'Likes': '4500',
#   'Comments': '147',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'wIUTD1FTnus',
#   'Title': 'Here’s to the humanity and the lion spirit displayed by our heroes! 🦁💪🏻#ChennaiFloods',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/wIUTD1FTnus/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-06T10:54:06Z',
#   'Duration': 'PT39S',
#   'Views': '31196',
#   'Likes': '4357',
#   'Comments': '25',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '8oH0atPDiwY',
#   'Title': 'Thalaivan Irukindraan and more...| IPL 2024 Retentions ft. Kasi Sir',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/8oH0atPDiwY/default.jpg',
#   'Description': "Dive into Kasi Sir's insights on the upcoming season, uncovering strategies for player retentions, Thalaivan's part in 2024, and the rationale behind player releases.",
#   'Published_Date': '2023-11-28T12:31:23Z',
#   'Duration': 'PT3M43S',
#   'Views': '258426',
#   'Likes': '12298',
#   'Comments': '569',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'kZ1gzu3IxGg',
#   'Title': 'Joy of 2023 - The Pride Showreel',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/kZ1gzu3IxGg/default.jpg',
#   'Description': 'As we prepare ourselves to embrace a new journey forward, here’s\nrewinding the season that was!',
#   'Published_Date': '2023-11-26T11:05:45Z',
#   'Duration': 'PT3M26S',
#   'Views': '61741',
#   'Likes': '5893',
#   'Comments': '183',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 's-hLe2bZeRs',
#   'Title': 'Everything about the final match up all at once under a minute for you!💪🏽🇮🇳  @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/s-hLe2bZeRs/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-19T04:54:40Z',
#   'Duration': 'PT1M1S',
#   'Views': '24722',
#   'Likes': '2331',
#   'Comments': '15',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '0xxMPPGuhL8',
#   'Title': 'Whistle For Blue ft. CWC 2023 - #INDvNZ',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/0xxMPPGuhL8/default.jpg',
#   'Description': 'Watch our Superfans from Mumbai send in their whistles to 🇮🇳 for the Semi finals against New Zealand!\nCOME ON INDIA! 💪\n\n#whistle4blue #cwc23',
#   'Published_Date': '2023-11-15T07:48:21Z',
#   'Duration': 'PT2M13S',
#   'Views': '4718',
#   'Likes': '458',
#   'Comments': '19',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'fha8LqqIPPw',
#   'Title': 'Here’s Badri taking his pick under a min! 🥳🇮🇳#INDvNZ #CWC23  @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/fha8LqqIPPw/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-15T07:43:57Z',
#   'Duration': 'PT1M1S',
#   'Views': '6057',
#   'Likes': '1146',
#   'Comments': '3',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '4twOsBNsEHc',
#   'Title': 'Wishing you a Super Duper Diwali! 🥳💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/4twOsBNsEHc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-12T01:41:09Z',
#   'Duration': 'PT23S',
#   'Views': '31013',
#   'Likes': '4046',
#   'Comments': '35',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'YAbB6MTV-Sw',
#   'Title': 'Proteas vs Men In Blue | INDvSA World Cup Preview Ft. Albie Morkel and @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/YAbB6MTV-Sw/default.jpg',
#   'Description': 'It’s the battle of the bests at Kolkata and we’re joined by Albie Morkel as Badri breaks down the game ahead! \n\nIf you’re a superfan, be a part of the pride kingdom at www.chennaisuperkings.com',
#   'Published_Date': '2023-11-05T06:12:15Z',
#   'Duration': 'PT15M33S',
#   'Views': '5528',
#   'Likes': '443',
#   'Comments': '32',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'iBUYK18u7dI',
#   'Title': 'Albie Agrees! 🥳 Kohli Ko Bowling Do! 🙌Check out Albie in conversation with @CricItwithBadri   📹',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/iBUYK18u7dI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-05T05:08:18Z',
#   'Duration': 'PT47S',
#   'Views': '24120',
#   'Likes': '2321',
#   'Comments': '13',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '_AzP2F64qiQ',
#   'Title': 'Battle of the Blues| #INDvSL CWC 2023 Preview ft. Muttiah Muralitharan and @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/_AzP2F64qiQ/default.jpg',
#   'Description': 'Revisiting his glory days in blue, our spinner Super King Muttiah Muralitharan chats with Badri ahead of the INDvSL world cup clash at Wankhede! \n\nIf you are a superfan, join our pride kingdom at www.chennaisuperkings.com\n\n#whistle4blue #cwc23',
#   'Published_Date': '2023-11-02T03:46:54Z',
#   'Duration': 'PT14M17S',
#   'Views': '4603',
#   'Likes': '442',
#   'Comments': '17',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'j--OAtEOFPs',
#   'Title': 'Watch it fully or it might go right over your head! 😉🥳',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/j--OAtEOFPs/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-01T09:52:18Z',
#   'Duration': 'PT16S',
#   'Views': '65375',
#   'Likes': '5589',
#   'Comments': '16',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'uIBy9dSPJXc',
#   'Title': 'Watch Badri pick his favourites under a min! 🥳🔥#INDvENG #CWC23 @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/uIBy9dSPJXc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-29T06:23:36Z',
#   'Duration': 'PT1M1S',
#   'Views': '7860',
#   'Likes': '1105',
#   'Comments': '4',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'c-Elhx5OyH4',
#   'Title': 'A famous win and a victory lap! - Whistles from Chepauk ft.#PAKvAFG',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/c-Elhx5OyH4/default.jpg',
#   'Description': "A true testament of the passion for the game was displayed by the Anbuden crowd as they stood in ovation for the Afghan team yesterday! Here's the next epsiode in Whistles from Chepauk! \n\nIf you are a super fan, become a part of the pride kingdom at www.chennaisuperkings.com",
#   'Published_Date': '2023-10-24T11:04:30Z',
#   'Duration': 'PT2M3S',
#   'Views': '7489',
#   'Likes': '642',
#   'Comments': '19',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '7yqd_b-cSHo',
#   'Title': 'The Contest of Blackcaps and Men in Blue |  #INDvNZ Preview ft. Scott Styris and @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/7yqd_b-cSHo/default.jpg',
#   'Description': 'As we prepare to face our ghosts of 2019, we are joined by Scott Styris our former Super King from the land of Kiwis with @CricItwithBadri to bring you the preview for #INDvNZ \n\nIf you are a superfan, join the pride kingdom at www.chennaisuperkings.com\n\n#whistle4blue #cwc23',
#   'Published_Date': '2023-10-21T15:30:59Z',
#   'Duration': 'PT18M54S',
#   'Views': '4521',
#   'Likes': '438',
#   'Comments': '17',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'PNgsFF8daGY',
#   'Title': 'One straight answer! What’s your pick? 🥳Presenting the first of Kings Picks!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/PNgsFF8daGY/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-20T15:04:06Z',
#   'Duration': 'PT19S',
#   'Views': '222152',
#   'Likes': '18888',
#   'Comments': '85',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '8hbxvnj-02E',
#   'Title': 'Whistles from Chepauk - World Cup Edition | New Zealand vs Afghanistan',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/8hbxvnj-02E/default.jpg',
#   'Description': 'From a thrilling contest to the Santner chants, Anbuden hosted a great game of cricket and the superfans made it even better! \n\nIf you are a superfan, become a part of the pride kingdom at www.chennaisuperkings.com',
#   'Published_Date': '2023-10-19T07:58:41Z',
#   'Duration': 'PT1M41S',
#   'Views': '3477',
#   'Likes': '408',
#   'Comments': '15',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '9LxOTWZawoU',
#   'Title': "Here's the #INDvBAN preview in a minute! ⏳#CWC23 @CricItwithBadri",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/9LxOTWZawoU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-19T06:58:54Z',
#   'Duration': 'PT1M1S',
#   'Views': '9713',
#   'Likes': '1110',
#   'Comments': '6',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'KOGmZxI9jJw',
#   'Title': 'Whistles and Navaratri? We say bring on the garba groove! 🥳🙌#WhistlePodu #Navratri @Coca-Cola',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/KOGmZxI9jJw/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-17T13:35:07Z',
#   'Duration': 'PT44S',
#   'Views': '137818',
#   'Likes': '15153',
#   'Comments': '66',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '98brRsgZ5cE',
#   'Title': 'Whistles and Navaratri? We say bring on the garba groove! 🥳🙌#WhistlePodu #Navratri @Coca-Cola',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/98brRsgZ5cE/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-17T13:31:07Z',
#   'Duration': 'PT44S',
#   'Views': '36391',
#   'Likes': '5618',
#   'Comments': '22',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '8CoILI6ThNc',
#   'Title': 'Whistles of Chepauk - World Cup Edition - Ep. 02 #NZvBAN',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/8CoILI6ThNc/default.jpg',
#   'Description': 'Still hearing the sound of whistles from the Friday clash of NZvBAN! 🥳💥\n\nIf you are a superfan, become a part of the pride kingdom at www.chennaisuperkings.com',
#   'Published_Date': '2023-10-15T12:29:02Z',
#   'Duration': 'PT2M22S',
#   'Views': '6109',
#   'Likes': '648',
#   'Comments': '17',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'b3-rS0baUrA',
#   'Title': 'Anbuden cheering every #CWC23 match 🥹🫶🏼🥳#BANvNZ',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/b3-rS0baUrA/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-13T14:05:33Z',
#   'Duration': 'PT24S',
#   'Views': '30253',
#   'Likes': '2112',
#   'Comments': '6',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '7CsqpL0R5J0',
#   'Title': 'All about the Afghan clash under a minute Ft. Badri💥🤩#INDvAFG #CWC23 #Whistle4Blue',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/7CsqpL0R5J0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-11T07:21:05Z',
#   'Duration': 'PT57S',
#   'Views': '9172',
#   'Likes': '1106',
#   'Comments': '5',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'e4yOuMhD7xY',
#   'Title': 'Smiling because it’s Chennai! 🤩',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/e4yOuMhD7xY/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-11T06:41:13Z',
#   'Duration': 'PT18S',
#   'Views': '58617',
#   'Likes': '7372',
#   'Comments': '21',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'QaxBNasNL_s',
#   'Title': 'Whistles From Chepauk Once Again - World Cup Edition | #INDvAUS',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/QaxBNasNL_s/default.jpg',
#   'Description': "India's World Cup campaign got off to a roaring start at Anbuden and the Knowledgeable Cricket Crowd came in large numbers to #Whistle4Blue \n\nHere's all the fanfare from last night! \n\nIf you're a superfan, become a part of the pride kingdom at www.chennaisuperkings.com \n\n#whistle4blue #CWC23",
#   'Published_Date': '2023-10-09T12:03:18Z',
#   'Duration': 'PT3M25S',
#   'Views': '4833',
#   'Likes': '615',
#   'Comments': '22',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'AVNLIYL23go',
#   'Title': '8 October 2023',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/AVNLIYL23go/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-08T17:35:27Z',
#   'Duration': 'PT24S',
#   'Views': '19277',
#   'Likes': '2387',
#   'Comments': '13',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'xWx0KTT_lYI',
#   'Title': "All the action under a min! Here's Badri with the #INDvAUS Preview! 🥳🇮🇳#Whistle4Blue #CWC23",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/xWx0KTT_lYI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-08T07:55:28Z',
#   'Duration': 'PT1M',
#   'Views': '5543',
#   'Likes': '942',
#   'Comments': '2',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '5ksUpqdLHfc',
#   'Title': 'Chepauk is Ready! Gearing up for the World Cup 2023',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/5ksUpqdLHfc/default.jpg',
#   'Description': "Get set and Whistle! Take a peak into the labour of Yellove that went behind to bring the clash of the titans to life at the big stage! \n\nIf you're a superfan, become a part of the pride kingdom at www.chennaisuperkings.com \n\n#whistle4blue #CWC23 #INDvAUS",
#   'Published_Date': '2023-10-08T05:55:42Z',
#   'Duration': 'PT17M46S',
#   'Views': '18370',
#   'Likes': '1678',
#   'Comments': '63',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'WB4Ml8yjC2k',
#   'Title': 'Curtain Raiser for the World Cup! | #INDvAUS Preview ft. Mike Hussey and @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/WB4Ml8yjC2k/default.jpg',
#   'Description': "The time is here to march into Anbuden and #whistle4blue ! Join the conversation as Mr. Cricket and Mr. Dependable break down the #INDvAUS clash tomorrow! \n\nIf you're a superfan, become a part of the pride kingdom at www.chennaisuperkings.com \n\n#whistle4blue #CWC23 @CricItwithBadri",
#   'Published_Date': '2023-10-07T07:30:11Z',
#   'Duration': 'PT13M57S',
#   'Views': '7946',
#   'Likes': '572',
#   'Comments': '22',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'rXT9J3j0mPY',
#   'Title': 'The classic Mr. Cricket and Mr. Dependable partnership! But with a #INDvAUS twist!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/rXT9J3j0mPY/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-07T05:48:25Z',
#   'Duration': 'PT47S',
#   'Views': '10907',
#   'Likes': '1286',
#   'Comments': '6',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '98W-G7hEPvY',
#   'Title': "CWC 23' with CWB is out to watch on all our platforms  🫶",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/98W-G7hEPvY/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-04T13:08:37Z',
#   'Duration': 'PT53S',
#   'Views': '12032',
#   'Likes': '1389',
#   'Comments': '9',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '2jU1xTBLBGs',
#   'Title': 'Anbuden Varuga to Singara Chennai! 🥳🙏🏽We are #CWC23 ready 🇮🇳💥#Whistle4Blue',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/2jU1xTBLBGs/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-04T09:46:28Z',
#   'Duration': 'PT43S',
#   'Views': '65478',
#   'Likes': '5261',
#   'Comments': '15',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'lqjFpog8ZcA',
#   'Title': 'Cricket World Cup 2023 Preview ft. @CricItwithBadri',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/lqjFpog8ZcA/default.jpg',
#   'Description': 'Whistle up and welcome this Cricket World Cup 2023 with Namma Mr. Dependable Subramaniam Badrinath! \n\nYou’re in for a treat with loads of content coming your way from match previews, expert analysis to post match reactions starting from this preview to the tournament! \n\nSo get set! @CricItwithBadri \n\nIf you’re a superfan, become a part of the pride kingdom at www.chennaisuperkings.com  \n\n#WhistlePodu #CWC2023',
#   'Published_Date': '2023-10-03T14:42:06Z',
#   'Duration': 'PT9M41S',
#   'Views': '17422',
#   'Likes': '1061',
#   'Comments': '53',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'KVhfaeC1LN4',
#   'Title': 'Every frame is a core memory at the Wanderers! ⏪📸#WhistleForJoburg  #Yellove 🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/KVhfaeC1LN4/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-09-24T18:49:56Z',
#   'Duration': 'PT11S',
#   'Views': '32553',
#   'Likes': '3639',
#   'Comments': '11',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'w1tx7gH4-2w',
#   'Title': "Reliving the last over to the return in blue - Shivam Dube's thrill ride - Lions Up Close",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/w1tx7gH4-2w/default.jpg',
#   'Description': 'From winning the title in IPL to making a comeback into the Indian side and now representing India at the Asian Games, the story of Shivam Dube is surely a remarkable one of redemption! \n\n#WhistlePodu #Yellove',
#   'Published_Date': '2023-09-23T16:03:51Z',
#   'Duration': 'PT11M30S',
#   'Views': '30442',
#   'Likes': '2522',
#   'Comments': '103',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'fx8PhBgkiv8',
#   'Title': 'City That Whistles - Madras Day 2023 Special',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/fx8PhBgkiv8/default.jpg',
#   'Description': "There's A S M R in MADRAS! Here's a whistle from every corner of the city and the unifying emotion! \n\n#MadrasDay #WhistlePodu",
#   'Published_Date': '2023-08-22T13:25:30Z',
#   'Duration': 'PT1M14S',
#   'Views': '13446',
#   'Likes': '1283',
#   'Comments': '41',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'baLQHOTWm3o',
#   'Title': 'Madras ft. Super Kings | Madras Day 2023  Special',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/baLQHOTWm3o/default.jpg',
#   'Description': 'Indulge in the Madras Sentiment from the Singams of the soil!\n\n#MadrasDay2023 #whistlepodu',
#   'Published_Date': '2023-08-22T09:43:37Z',
#   'Duration': 'PT6M19S',
#   'Views': '23043',
#   'Likes': '1954',
#   'Comments': '106',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'Erkjh_RM5y0',
#   'Title': 'That moment when a billion hearts sang in unison! 🇮🇳💛#IndependenceDay 📹: @icc',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/Erkjh_RM5y0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-08-15T13:22:02Z',
#   'Duration': 'PT1M1S',
#   'Views': '41140',
#   'Likes': '5581',
#   'Comments': '29',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'm_wYkpVaWCs',
#   'Title': 'Buchi Babu Tournament is the first stepping stone into big cricket - Kris Srikkanth | Press Meet',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/m_wYkpVaWCs/default.jpg',
#   'Description': 'The Tournament that holds so much of history is back!\n\nListen to what Kris Srikkanth & other dignitaries had to say from the Launch  📽️\n\n#BuchiBabuTournament',
#   'Published_Date': '2023-08-12T13:36:15Z',
#   'Duration': 'PT2M38S',
#   'Views': '9728',
#   'Likes': '803',
#   'Comments': '28',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'HYzJBwP40t0',
#   'Title': 'With Yellove and Gratitude, ✍🏻The Birthday Swingam! 🦁 #SuperBirthday #WhistlePodu #Yellove 🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/HYzJBwP40t0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-08-07T15:48:30Z',
#   'Duration': 'PT40S',
#   'Views': '106183',
#   'Likes': '12536',
#   'Comments': '62',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '6zv8mzeqZn0',
#   'Title': 'All time XI of Dube is as strong as a Clay 😍Pick yours here📎 bit.ly/42k8NkQ',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/6zv8mzeqZn0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-08-05T11:17:17Z',
#   'Duration': 'PT38S',
#   'Views': '155783',
#   'Likes': '12799',
#   'Comments': '90',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'IjsR8UBoUkE',
#   'Title': 'Win-tage Cars ft.Thala! #WhistlePodu #Yellove🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/IjsR8UBoUkE/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-08-03T14:16:57Z',
#   'Duration': 'PT45S',
#   'Views': '46944',
#   'Likes': '6174',
#   'Comments': '33',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'f1gnaV4sWYo',
#   'Title': 'That sounds Mo like a perfect team 😎Pick yours here📎 bit.ly/42k8NkQ',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/f1gnaV4sWYo/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-07-21T09:10:58Z',
#   'Duration': 'PT37S',
#   'Views': '69015',
#   'Likes': '6189',
#   'Comments': '40',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '85adJ60bQqk',
#   'Title': "Thala's birthday gift 🎥💛#CelebratingThala #WhistlePodu 🦁",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/85adJ60bQqk/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-07-08T11:26:55Z',
#   'Duration': 'PT54S',
#   'Views': '199593',
#   'Likes': '32277',
#   'Comments': '330',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'zdZmopaH8vA',
#   'Title': 'The THALA Emotion - MS Dhoni Birthday Special | #CelebratingThala',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/zdZmopaH8vA/default.jpg',
#   'Description': "It's his day, our day! Join in as we celebrate the man who leads the pride! \n\n#CelebratingThala #WhistlePodu #Yellove",
#   'Published_Date': '2023-07-07T09:08:20Z',
#   'Duration': 'PT3M56S',
#   'Views': '229748',
#   'Likes': '22757',
#   'Comments': '1096',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'r88fWNdYmPc',
#   'Title': 'Test Cricket’s an art and Bens got those master Strokes! 💪🏻#TheAshes #WhistlePodu #Yellove 🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/r88fWNdYmPc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-07-04T11:17:36Z',
#   'Duration': 'PT44S',
#   'Views': '64865',
#   'Likes': '7710',
#   'Comments': '30',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'o29L2ysDYeY',
#   'Title': "Does your All time XI match with that of Conway's ?Pick here 🔗 https://bit.ly/3D1WtKk",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/o29L2ysDYeY/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-07-03T10:46:32Z',
#   'Duration': 'PT42S',
#   'Views': '66379',
#   'Likes': '8893',
#   'Comments': '98',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'DntAi1keBkg',
#   'Title': 'The Season that was - Rewind to Summer of 2023 #WhistlePodu',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/DntAi1keBkg/default.jpg',
#   'Description': "The Season that was! Here's the super cut of the summer of 2023! \n\n#ReliveChampions23 #WhistlePodu",
#   'Published_Date': '2023-06-30T14:14:38Z',
#   'Duration': 'PT5M30S',
#   'Views': '281207',
#   'Likes': '14842',
#   'Comments': '268',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'sWldDPznq60',
#   'Title': 'Moments that keep reeling forever in our hearts! 💛  Be a part of it 🔗 https://bit.ly/3NQ6mRI',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/sWldDPznq60/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-06-29T14:11:59Z',
#   'Duration': 'PT33S',
#   'Views': '197001',
#   'Likes': '22348',
#   'Comments': '128',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'R6v4PyiDOMI',
#   'Title': 'Your Monday evening Blockbuster!💥🥳#WhistlePodu #Yellove 🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/R6v4PyiDOMI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-06-26T12:55:50Z',
#   'Duration': 'PT37S',
#   'Views': '93537',
#   'Likes': '12177',
#   'Comments': '66',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '51BFx3J2Ru4',
#   'Title': 'Ashes Action Block Ft. Ben Stokes and Moeen Ali',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/51BFx3J2Ru4/default.jpg',
#   'Description': 'We’re always up for a taste of test cricket! Here’s Ben and Mo on the format and #TheAshes Challenge \n\n#WhistlePodu #Yellove 💛🦁',
#   'Published_Date': '2023-06-16T10:09:12Z',
#   'Duration': 'PT3M7S',
#   'Views': '33440',
#   'Likes': '1807',
#   'Comments': '65',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'xlripGf89Aw',
#   'Title': 'Journey from Jharkhand to Chennai | Anbuden Diaries ft. Rajiv Kumar',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/xlripGf89Aw/default.jpg',
#   'Description': 'The Journey from Jharkhand to becoming an integral part of the Super Kings coaching setup!\n\nAnbuden Diaries ft. Rajiv Kumar 📽️🔗\n\n#WhistlePodu #Yellove 🦁💛',
#   'Published_Date': '2023-06-08T08:17:10Z',
#   'Duration': 'PT7M25S',
#   'Views': '21483',
#   'Likes': '1415',
#   'Comments': '91',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'Q4wsTEV8_XM',
#   'Title': 'Ajinkya Rahane opens up on the India vs Australia Memories #INDvAUS | #WTCFinal',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/Q4wsTEV8_XM/default.jpg',
#   'Description': "Ajju's memories on the Aussie tussle 📹\nFull Video 🔗https://bit.ly/3Ca9t02\n\n#INDvAUS #WhistlePodu #Yellove 🦁💛",
#   'Published_Date': '2023-06-05T11:37:30Z',
#   'Duration': 'PT1M56S',
#   'Views': '29642',
#   'Likes': '2163',
#   'Comments': '81',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'XZ0n5vOCj6U',
#   'Title': 'Going Ben Strokes on his BDAY! 💥#SuperBirthday #WhistlePodu #Yellove 🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/XZ0n5vOCj6U/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-06-04T15:54:56Z',
#   'Duration': 'PT27S',
#   'Views': '171938',
#   'Likes': '20250',
#   'Comments': '117',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'W4P5AyK7Ues',
#   'Title': 'Thala is an emotion 🥹#WhistlePodu #Yellove 🦁💛',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/W4P5AyK7Ues/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-06-03T13:44:09Z',
#   'Duration': 'PT38S',
#   'Views': '473026',
#   'Likes': '67145',
#   'Comments': '337',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'RtD4q4LnLUw',
#   'Title': 'Celebrating the Super Kings Way | #CHAMPION5 #IPL2023',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/RtD4q4LnLUw/default.jpg',
#   'Description': 'Peek into the Celebrations of the Super Kings inside the Dressing Room, Team Bus, Hotel and more..!\n\n#WhistlePodu #Yellove',
#   'Published_Date': '2023-06-02T06:40:40Z',
#   'Duration': 'PT4M33S',
#   'Views': '1853195',
#   'Likes': '81210',
#   'Comments': '1567',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'WxbZtVJLID4',
#   'Title': 'CSK #SuperChampions celebrations - IPL 2023 Final | #CSKvGT',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/WxbZtVJLID4/default.jpg',
#   'Description': '5INALLY THE CELEBRATIONS! 🥳\n\n#CHAMPION5 #WhistlePodu #Yellove 🦁💛',
#   'Published_Date': '2023-05-30T01:56:52Z',
#   'Duration': 'PT26S',
#   'Views': '1298288',
#   'Likes': '66318',
#   'Comments': '2359',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '9OPmzW31nzk',
#   'Title': 'Action Unfiltered - The Last Grind before the Finale',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/9OPmzW31nzk/default.jpg',
#   'Description': 'As we get set for the grand title challenge, soak up in the raw action from Ahmedabad!',
#   'Published_Date': '2023-05-28T11:45:48Z',
#   'Duration': 'PT3M49S',
#   'Views': '182580',
#   'Likes': '7450',
#   'Comments': '249',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'MbzuFYeq4aU',
#   'Title': 'IPL Final : Chennai Super Kings vs Gujarat Titans Match Preview ft. Stephen Fleming',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/MbzuFYeq4aU/default.jpg',
#   'Description': 'One final Steph 🗣️📹\n\n#CSKvGT #WhistlePodu #Yellove 🦁💛',
#   'Published_Date': '2023-05-28T11:18:46Z',
#   'Duration': 'PT3M20S',
#   'Views': '89760',
#   'Likes': '4812',
#   'Comments': '264',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'fGHl5k_PyNE',
#   'Title': 'Thank You, Chepauk! - Rewinding the memories of the summer!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/fGHl5k_PyNE/default.jpg',
#   'Description': "Memories of home that still stand fresh! What's your special moment of the Summer, Makkaley? \n\n#WhistlePodu #Yellove 🦁💛",
#   'Published_Date': '2023-05-28T08:48:51Z',
#   'Duration': 'PT1M49S',
#   'Views': '132592',
#   'Likes': '7122',
#   'Comments': '234',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
# ...
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'z3Lw8mca6Gc',
#   'Title': "'Can you do a full twirl please?' Shane Watson's cutest shoot day",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/z3Lw8mca6Gc/default.jpg',
#   'Description': 'Thala Dhoni, Chinna Thala Raina, Champion Bravo and Pulavar Harbhajan Singh are along side Watto Man in a super cute shoot from IPL 2019 for The Muthoot Group. #HappyBirthdayWatto #WhistlePodu',
#   'Published_Date': '2020-06-17T12:41:41Z',
#   'Duration': 'PT57S',
#   'Views': '1109040',
#   'Likes': '35124',
#   'Comments': '318',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'GkLMbkZSNmA',
#   'Title': 'Mahi Maar Raha Hai - The Story of How the Moon Was Created',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/GkLMbkZSNmA/default.jpg',
#   'Description': '#MSDhoni #Thala #WhistlePodu #CSK #SuperFanMade',
#   'Published_Date': '2020-06-16T15:29:49Z',
#   'Duration': 'PT11S',
#   'Views': '47330',
#   'Likes': '4322',
#   'Comments': '172',
#   'Favourite_count': '0',
#   'Definition': 'sd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'Yn6P2JH-CqY',
#   'Title': "How to stay motivated? The Lion's Way.",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/Yn6P2JH-CqY/default.jpg',
#   'Description': 'No better time to receive this. No better time to share it. How to stay motivated? #BringOutTheLionInYou #SingaPaadhai #WhistlePodu 🦁💛',
#   'Published_Date': '2020-06-16T08:00:41Z',
#   'Duration': 'PT1M23S',
#   'Views': '19246',
#   'Likes': '2210',
#   'Comments': '96',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'yjvaV-08alU',
#   'Title': "Harbhajan Singh's daughter Hinaya aces an innovative indoor activity",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/yjvaV-08alU/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-06-14T05:00:15Z',
#   'Duration': 'PT2M28S',
#   'Views': '19338',
#   'Likes': '1026',
#   'Comments': '25',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'HkqL0n4SxGY',
#   'Title': 'Stay Home Stay Fit',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/HkqL0n4SxGY/default.jpg',
#   'Description': "Stay Home you all know, but here's a King'ly reminder to Stay Fit! #WhistlePodu www.chennaisuperkings.com 🦁💛",
#   'Published_Date': '2020-06-11T11:15:24Z',
#   'Duration': 'PT32S',
#   'Views': '20001',
#   'Likes': '1445',
#   'Comments': '55',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'iu1FSBl5uWw',
#   'Title': 'Thala Dhoni drives around his latest beast - a tractor!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/iu1FSBl5uWw/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-06-02T15:00:42Z',
#   'Duration': 'PT45S',
#   'Views': '418219',
#   'Likes': '22215',
#   'Comments': '370',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'ValoXnlnR2s',
#   'Title': "'Lightning' Dhoni takes Ziva on a bike ride",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/ValoXnlnR2s/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-06-02T14:11:11Z',
#   'Duration': 'PT38S',
#   'Views': '147503',
#   'Likes': '9130',
#   'Comments': '112',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '-adUhxh8qwg',
#   'Title': '"Mahi bhai said I\'ve to hit each and every ball out of the park!" - Piyush Chawla',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/-adUhxh8qwg/default.jpg',
#   'Description': 'What followed next is...Vaanam Thottu Ponaa!\n#WhistlePodu #Yellove',
#   'Published_Date': '2020-06-01T14:00:58Z',
#   'Duration': 'PT1M',
#   'Views': '3549494',
#   'Likes': '103577',
#   'Comments': '1159',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'T48T5FLfq7M',
#   'Title': "Sakshi on Dhoni's low-profile social media presence and their plan post lockdown",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/T48T5FLfq7M/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-05-31T12:30:34Z',
#   'Duration': 'PT2M34S',
#   'Views': '431979',
#   'Likes': '16549',
#   'Comments': '296',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'Jqqcr57v1RQ',
#   'Title': 'Suresh Raina picks his Quarantine partners',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/Jqqcr57v1RQ/default.jpg',
#   'Description': '#ChinnaThala #WhistlePodu  #Yellove',
#   'Published_Date': '2020-05-29T13:06:58Z',
#   'Duration': 'PT1M23S',
#   'Views': '22487',
#   'Likes': '1358',
#   'Comments': '37',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '0LyAtyGRy2s',
#   'Title': "The Daddies Army's Ultimate Comeback",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/0LyAtyGRy2s/default.jpg',
#   'Description': '#WhistlePodu #Yellove',
#   'Published_Date': '2020-05-28T12:30:11Z',
#   'Duration': 'PT11M18S',
#   'Views': '2403703',
#   'Likes': '104875',
#   'Comments': '1733',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'AMgchX-vpMQ',
#   'Title': 'The Kings of Good Times',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/AMgchX-vpMQ/default.jpg',
#   'Description': '#OnceUponAWhistle #WhistlePodu #CSK',
#   'Published_Date': '2020-05-24T12:20:45Z',
#   'Duration': 'PT1M26S',
#   'Views': '37234',
#   'Likes': '2525',
#   'Comments': '85',
#   'Favourite_count': '0',
#   'Definition': 'sd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'Zrgz85_vFrE',
#   'Title': 'Bravo singing and dancing to Run D World in CSK Dressing Room',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/Zrgz85_vFrE/default.jpg',
#   'Description': '#WhistlePodu',
#   'Published_Date': '2020-05-23T06:15:48Z',
#   'Duration': 'PT1M55S',
#   'Views': '75413',
#   'Likes': '2887',
#   'Comments': '51',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'kqdeyegtNpo',
#   'Title': '"I thought Shardul was a tail-ender and gonna get out after 1...but he batted even better than me!"',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/kqdeyegtNpo/default.jpg',
#   'Description': 'Faf du Plessis and Shardul Thakur take you through their incredible partnership out in the middle during the fabled Q1 of 2018, with every little detail there is from either ends! #WhistlePodu #Yellove #FafulouslyYours 🦁💛',
#   'Published_Date': '2020-05-22T14:19:23Z',
#   'Duration': 'PT7M44S',
#   'Views': '142844',
#   'Likes': '5568',
#   'Comments': '114',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'XHPt-VSyaHQ',
#   'Title': '62 for 6 and then...WHAT THE FAF!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/XHPt-VSyaHQ/default.jpg',
#   'Description': 'The incredible Qualifier 1 of IPL 2018 shall always be Fafulous for his pistha innings of 67* off 42 to take the Super Kings to the Finals. #WhistlePodu #Yellove 🦁💛',
#   'Published_Date': '2020-05-22T07:09:13Z',
#   'Duration': 'PT24S',
#   'Views': '102142',
#   'Likes': '9223',
#   'Comments': '75',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'kaQd3sBsUVQ',
#   'Title': '"Nobody can swear at me in Tamil...I know everything about it!" - Piyush Chawla',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/kaQd3sBsUVQ/default.jpg',
#   'Description': '#WhistlePodu #AnbuDenLions',
#   'Published_Date': '2020-05-21T12:02:57Z',
#   'Duration': 'PT48S',
#   'Views': '32190',
#   'Likes': '1264',
#   'Comments': '39',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '1cMUbGPEq24',
#   'Title': "DJ Bravo playing with his son Dwade, don't miss the yellove fish",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/1cMUbGPEq24/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-05-20T16:25:56Z',
#   'Duration': 'PT1M8S',
#   'Views': '20935',
#   'Likes': '1152',
#   'Comments': '28',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '5enG0bNi8wI',
#   'Title': '"I thought MSD would seal the deal and I wouldn\'t have to bat!" - Mitchell Santner',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/5enG0bNi8wI/default.jpg',
#   'Description': 'Mitchell Santner on the incredible chase against RR. #AnbuDenLions #WhistlePodu',
#   'Published_Date': '2020-05-20T14:03:58Z',
#   'Duration': 'PT2M33S',
#   'Views': '77003',
#   'Likes': '3398',
#   'Comments': '70',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '8c-ozwqt_1g',
#   'Title': 'Chumma Kizhi ft. Thala',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/8c-ozwqt_1g/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-05-19T12:17:29Z',
#   'Duration': 'PT12S',
#   'Views': '210710',
#   'Likes': '11674',
#   'Comments': '157',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '2UNjb0t1z6U',
#   'Title': 'Gracia Raina having a beach of a time',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/2UNjb0t1z6U/default.jpg',
#   'Description': 'Song: Sippi Irukkudhu',
#   'Published_Date': '2020-05-19T09:33:49Z',
#   'Duration': 'PT50S',
#   'Views': '50039',
#   'Likes': '3819',
#   'Comments': '31',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'zrEhoeCYq-I',
#   'Title': 'M Vijay sings a Chandrababu Song',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/zrEhoeCYq-I/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-05-18T12:27:55Z',
#   'Duration': 'PT26S',
#   'Views': '18525',
#   'Likes': '924',
#   'Comments': '29',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'bvYGceFGiy4',
#   'Title': 'Harbhajan was always a Silambarasan!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/bvYGceFGiy4/default.jpg',
#   'Description': '#AnbuDenLions #WhistlePodu',
#   'Published_Date': '2020-05-17T12:27:27Z',
#   'Duration': 'PT1M23S',
#   'Views': '22037',
#   'Likes': '1111',
#   'Comments': '22',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'XtQrUSSxT5A',
#   'Title': "Ziva Dhoni on a bike as papa Dhoni makes a 'handy' cameo",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/XtQrUSSxT5A/default.jpg',
#   'Description': '',
#   'Published_Date': '2020-05-16T13:45:13Z',
#   'Duration': 'PT16S',
#   'Views': '7628178',
#   'Likes': '283492',
#   'Comments': '488',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'O6-0WGh8Mug',
#   'Title': 'Super Birthday to Gracia Raina, the bundle of joy',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/O6-0WGh8Mug/default.jpg',
#   'Description': 'Birthday gives us joy, but there are times when birthday gets its joy. Super Birthday to that very bundle of joy! #HappyBirthday #WhistlePodu #Yellove #Raina 🦁💛',
#   'Published_Date': '2020-05-15T04:47:31Z',
#   'Duration': 'PT52S',
#   'Views': '46900',
#   'Likes': '2338',
#   'Comments': '88',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '1Z2YZS-KlUo',
#   'Title': 'Raina and Rohit pick a combined CSK-MI team where the water boys and assistant coaches are legendary',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/1Z2YZS-KlUo/default.jpg',
#   'Description': '#ChinnaThala #Hitman #WhistlePodu #Yellove',
#   'Published_Date': '2020-05-14T14:59:05Z',
#   'Duration': 'PT1M14S',
#   'Views': '24592',
#   'Likes': '1377',
#   'Comments': '82',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'p232zxt6yTo',
#   'Title': "Bravo and Rayudu's legendary bromance is too good to be true",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/p232zxt6yTo/default.jpg',
#   'Description': 'There are friends. There are brothers. And then there are #Bravo and #Rayudu. This must-watch ultimate Mustafa Mustafa reel proves that #Champion and #Bahubali are no less than Surya and Deva! #WhistlePodu #SuperFam 🦁💛',
#   'Published_Date': '2020-05-13T16:08:51Z',
#   'Duration': 'PT5M20S',
#   'Views': '1408728',
#   'Likes': '44387',
#   'Comments': '522',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': '_gjWNgtnzxY',
#   'Title': "Watto Man on Neelambari's TV",
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/_gjWNgtnzxY/default.jpg',
#   'Description': '#Padayappa #WattoMan #Watson #WhistlePodu #Yellove',
#   'Published_Date': '2020-05-12T06:25:25Z',
#   'Duration': 'PT48S',
#   'Views': '61770',
#   'Likes': '6447',
#   'Comments': '88',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'IwpUD8vyjo4',
#   'Title': 'Thala Dhoni is back in Yellove, dot!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/IwpUD8vyjo4/default.jpg',
#   'Description': '#WhistlePodu #Yellove #Dhoni #CSK',
#   'Published_Date': '2020-05-11T12:57:51Z',
#   'Duration': 'PT2M10S',
#   'Views': '1367881',
#   'Likes': '42143',
#   'Comments': '2138',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_Name': 'Chennai Super Kings',
#   'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'PVRCR0FqJow',
#   'Title': 'Because in reality, the Lionesses hunt!',
#   'Tags': None,
#   'Thumnail': 'https://i.ytimg.com/vi/PVRCR0FqJow/default.jpg',
#   'Description': 'Amma Endrazhaikaadha Uyir Illayey! #MothersDay #WhistlePodu',
#   'Published_Date': '2020-05-10T15:01:57Z',
#   'Duration': 'PT35S',
#   'Views': '91230',
#   'Likes': '5705',
#   'Comments': '60',
#   'Favourite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  ...]

# %%
#get comment information
def get_comment_info(video_ids):
    Comment_data=[]
    try:
            for video_id in video_ids:
                request=youtube.commentThreads().list(
                    part="snippet",
                    videoId=video_id,
                    maxResults=50
            )
            response=request.execute()

            for item in response['items']:
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet'][ 'textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet'][ 'publishedAt'])
                
                Comment_data.append(data)

    except:
        pass
    return Comment_data

# %%
comment_details=get_comment_info(Video_Ids)

# %%
comment_details
# Out:
# [{'Comment_Id': 'UgwjbhJ62Xk1u65RwKd4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'I am watching this in 2024',
#   'Comment_Author': '@heroaster7',
#   'Comment_Published': '2024-01-18T18:56:42Z'},
#  {'Comment_Id': 'UgykI7F4c-PJe_tn6XN4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Google CEO',
#   'Comment_Author': '@antonybenjamin602',
#   'Comment_Published': '2023-12-19T03:15:25Z'},
#  {'Comment_Id': 'UgwFoN_ijzhx8oLA0UJ4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'CSK op',
#   'Comment_Author': '@varunmundada7340',
#   'Comment_Published': '2023-11-03T10:09:19Z'},
#  {'Comment_Id': 'UgzgJ04skZ8tWVYsenB4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'I AM WATCH THIS VIDEO IN 2023',
#   'Comment_Author': '@LOKALDJ.',
#   'Comment_Published': '2023-10-18T09:45:35Z'},
#  {'Comment_Id': 'UgxZSzhaNlRdQCrSyZp4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Legend watching in 2023❤',
#   'Comment_Author': '@BHSTARK',
#   'Comment_Published': '2023-08-21T10:42:57Z'},
#  {'Comment_Id': 'UgzkGDEun26xYTwzmz94AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Big FAN of CSK ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@dark_x999',
#   'Comment_Published': '2023-07-30T10:15:50Z'},
#  {'Comment_Id': 'Ugw3u6pQ3cKDMMUE4k14AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'It&#39;s 2023 but yet it Never gets old',
#   'Comment_Author': '@gshrikaar5952',
#   'Comment_Published': '2023-06-30T15:20:51Z'},
#  {'Comment_Id': 'UgzwfulteGIqvh5i0fd4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'ONLY MAHI BHAI ❤❤❤❤',
#   'Comment_Author': '@identifygamer5633',
#   'Comment_Published': '2023-06-22T09:46:55Z'},
#  {'Comment_Id': 'Ugzd6wls_OXNTop0cLx4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '2023 💛Add 🏆 GOAT 🐐 Thala 👿',
#   'Comment_Author': '@satyabratamahalik',
#   'Comment_Published': '2023-06-01T20:25:48Z'},
#  {'Comment_Id': 'UgxNUTScr2ekzXJxdB54AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Legend watching After 14 years 😎',
#   'Comment_Author': '@satyabratamahalik',
#   'Comment_Published': '2023-06-01T20:25:14Z'},
#  {'Comment_Id': 'UgyVRY1DimGYOXl3uIN4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Sigma people watching after 14 years!!👌🤙',
#   'Comment_Author': '@q.kgaming',
#   'Comment_Published': '2023-06-01T06:51:52Z'},
#  {'Comment_Id': 'UgxXJD-tqKsscDut7yN4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Who all are watching After the 5th Trophy🏆🏆🏆🏆🏆',
#   'Comment_Author': '@rubesh6572',
#   'Comment_Published': '2023-05-31T11:43:28Z'},
#  {'Comment_Id': 'UgzGaM_BeBUmS-NQMLR4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '🏆💛🏆💛🏆💛🏆💛🏆💛🦁🦁🦁🦁🦁🦁🦁🦁🦁🦁',
#   'Comment_Author': '@sachu670',
#   'Comment_Published': '2023-05-30T11:25:04Z'},
#  {'Comment_Id': 'UgynGU9Jg3Nh7FESyHJ4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '💛💛💛💛😅',
#   'Comment_Author': '@artstudio1668',
#   'Comment_Published': '2023-05-30T05:52:47Z'},
#  {'Comment_Id': 'UgzzfRFzLBuRoy5AIxh4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'CSK WON THEIR 5TH TITLE ❤❤❤',
#   'Comment_Author': '@Chaitanya_07',
#   'Comment_Published': '2023-05-29T20:57:13Z'},
#  {'Comment_Id': 'UgwnEFovDAhWIskYcSF4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '28.05.23 final cancel and 29.05.23 match(GT vs CSK) season 16 winner CSK',
#   'Comment_Author': '@balaji.482',
#   'Comment_Published': '2023-05-28T20:05:59Z'},
#  {'Comment_Id': 'UgyDTbF74FfWfwDrCQV4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '💛💛💛💛',
#   'Comment_Author': '@XyzUnknown777',
#   'Comment_Published': '2023-05-24T11:39:12Z'},
#  {'Comment_Id': 'Ugwbn3d0_MQUAUR9JvV4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Ultra legends watching in 2023',
#   'Comment_Author': '@gokulkrishna4000',
#   'Comment_Published': '2023-05-20T15:14:54Z'},
#  {'Comment_Id': 'UgzBoEPivokZJtIztxJ4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Ultra legends watch after 14 years',
#   'Comment_Author': '@saivishwa4546',
#   'Comment_Published': '2023-05-19T17:29:35Z'},
#  {'Comment_Id': 'UgzdC6bkb_1pKAd7MNl4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'CSK 💛',
#   'Comment_Author': '@linoj678',
#   'Comment_Published': '2023-05-14T07:35:08Z'},
#  {'Comment_Id': 'Ugx2Iy25vQ3m2UNuPDB4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Ultra legends watching after 14yrs',
#   'Comment_Author': '@cinemamadness4995',
#   'Comment_Published': '2023-05-13T06:36:55Z'},
#  {'Comment_Id': 'UgxPgl5iZKQ1ZLWhqZJ4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '14 years back very sad for csk',
#   'Comment_Author': '@Rudra....Srivastav_7180',
#   'Comment_Published': '2023-05-11T08:25:42Z'},
#  {'Comment_Id': 'UgySv98J6E_imFygUgt4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Masterpiece csk❤',
#   'Comment_Author': '@entertainmentofficials7964',
#   'Comment_Published': '2023-05-07T08:05:33Z'},
#  {'Comment_Id': 'Ugxtp3984CiuQoAIhxV4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'WATCHING AFTER MAHI RETIRED IN ALL FORMET 😢',
#   'Comment_Author': '@BY_MURPHA',
#   'Comment_Published': '2023-05-01T08:51:20Z'},
#  {'Comment_Id': 'UgxzBLZw-M2yTu9Q_594AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'I&#39;m watching in 2023',
#   'Comment_Author': '@alone42099',
#   'Comment_Published': '2023-04-27T07:06:03Z'},
#  {'Comment_Id': 'UgzUaEHHth5l2MxT4F94AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'The Goats Watching After 13 Year 😂😂😂😂',
#   'Comment_Author': '@SANATAN4455',
#   'Comment_Published': '2023-04-27T06:31:43Z'},
#  {'Comment_Id': 'UgypeQSTqQFgSNEdwiV4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '2023 🔥🔥🔥',
#   'Comment_Author': '@SUMANDAS-pu4zr',
#   'Comment_Published': '2023-04-27T04:46:53Z'},
#  {'Comment_Id': 'UgwjJyKo8feNhB3BNIZ4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'its been 14 years',
#   'Comment_Author': '@vivekthombare3591',
#   'Comment_Published': '2023-04-26T18:16:04Z'},
#  {'Comment_Id': 'UgxQgB5MHQvgtU7Rp094AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '2023<br><a href="http://www.youtube.com/results?search_query=%23csk">#CSK</a>❤🔥',
#   'Comment_Author': '@jeffrinimmanuel2681',
#   'Comment_Published': '2023-04-23T18:40:10Z'},
#  {'Comment_Id': 'Ugx2pIvrcAd6uR5AV3N4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '14 years agooooooo',
#   'Comment_Author': '@galaxy2550',
#   'Comment_Published': '2023-04-23T13:01:33Z'},
#  {'Comment_Id': 'Ugxu0Zhe4DLZZH-997J4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Who is in 2023🎉🎉🎉🎉🎉',
#   'Comment_Author': '@galaxy2550',
#   'Comment_Published': '2023-04-23T13:01:14Z'},
#  {'Comment_Id': 'UgwruQ6r6VLfnCIfLpB4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'This is an remarkable start by the best franchise in the world',
#   'Comment_Author': '@user-ox9sv5og1n',
#   'Comment_Published': '2023-04-23T04:41:04Z'},
#  {'Comment_Id': 'Ugwkd3cg1dzx8jbEWkV4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Hello',
#   'Comment_Author': '@user-vq8ih1yb9e',
#   'Comment_Published': '2023-04-19T15:17:11Z'},
#  {'Comment_Id': 'UgwORbZs_G-3OdH8S0N4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Who are watching this video in 2023😭😭',
#   'Comment_Author': '@aryanmallick1358',
#   'Comment_Published': '2023-04-13T16:58:03Z'},
#  {'Comment_Id': 'UgyE8AB3B1qOF6Q3WXx4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Who watching in  2023 like plz😍😍',
#   'Comment_Author': '@d.n.rangaswamyswamy212',
#   'Comment_Published': '2023-04-12T04:37:25Z'},
#  {'Comment_Id': 'UgyR6rRaoHsfSVObOGl4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '<a href="http://www.youtube.com/results?search_query=%23whistle">#Whistle</a> podu',
#   'Comment_Author': '@user-vm1sd3hv7v',
#   'Comment_Published': '2023-04-10T07:42:32Z'},
#  {'Comment_Id': 'Ugz4mEFSR64mLvqZvpp4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Who is in 2023',
#   'Comment_Author': '@ary3552',
#   'Comment_Published': '2023-04-04T05:04:50Z'},
#  {'Comment_Id': 'Ugw9HRCaXJVEJbnDLSR4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '💛💛💛',
#   'Comment_Author': '@ravikumars3473',
#   'Comment_Published': '2023-03-30T07:46:28Z'},
#  {'Comment_Id': 'UgxAarkARNWIbdq3CS14AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Any one in 2023',
#   'Comment_Author': '@sharonsreerag7470',
#   'Comment_Published': '2023-03-03T11:25:48Z'},
#  {'Comment_Id': 'UgzoyNZWlQFTatotMHh4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Watching this after 14 years',
#   'Comment_Author': '@p.r.ksrimathicooking2976',
#   'Comment_Published': '2023-01-09T07:00:05Z'},
#  {'Comment_Id': 'UgxDKLNZH821t8hdGtZ4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Legends watching 2022',
#   'Comment_Author': '@otpgaming8098',
#   'Comment_Published': '2022-06-14T17:56:37Z'},
#  {'Comment_Id': 'UgyAxBP_KrfBI19jaO54AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'CSK 💥💯💯💯💯💯',
#   'Comment_Author': '@rahulwithmagic2440',
#   'Comment_Published': '2022-06-06T11:19:35Z'},
#  {'Comment_Id': 'Ugx7G_nQ5I0p81bAr894AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '😂😂',
#   'Comment_Author': '@omchastic18',
#   'Comment_Published': '2022-05-18T08:52:01Z'},
#  {'Comment_Id': 'UgxehcwIzjAAG6CVnx14AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Legends watching in 2022',
#   'Comment_Author': '@rupeshkala_boisar',
#   'Comment_Published': '2022-05-12T10:11:54Z'},
#  {'Comment_Id': 'Ugy_GVgObxehf3wwcX54AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '1st video of lions',
#   'Comment_Author': '@pranav6133',
#   'Comment_Published': '2022-05-07T06:05:09Z'},
#  {'Comment_Id': 'Ugx4MpmIaNZaoLlLLY94AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': '2022',
#   'Comment_Author': '@CRUZ4333',
#   'Comment_Published': '2022-05-05T17:16:13Z'},
#  {'Comment_Id': 'UgzsQAroTVdqLZxkRUR4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Anyone here during 4 may 2022, csk vs rcb',
#   'Comment_Author': '@shwinthomas4034',
#   'Comment_Published': '2022-05-04T16:14:13Z'},
#  {'Comment_Id': 'UgyziGH4N0kHTb-xS1d4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Jai csk jai thala 1st video dhoni forefather of cricket',
#   'Comment_Author': '@DANIRUDHGARLAPATI',
#   'Comment_Published': '2022-05-04T12:57:15Z'},
#  {'Comment_Id': 'UgwEmfdhsMiKAULQf5V4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'Those days 💛',
#   'Comment_Author': '@pritamdas337',
#   'Comment_Published': '2022-05-03T21:00:53Z'},
#  {'Comment_Id': 'UgytG-N8-Fzn1wDTQAV4AaABAg',
#   'Video_Id': 'cZNbDuibM5A',
#   'Comment_Text': 'muth nikal gya anthem sun k',
#   'Comment_Author': '@thecIown',
#   'Comment_Published': '2022-05-03T18:29:42Z'}]

# %%
#get playlist details

def get_playlist_details(channel_id):

        next_page_token=None
        All_data=[]
        while True:

                request=youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                response=request.execute()

                for item in response['items']:
                        data=dict(Playlist_Id=item['id'],
                                Title=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_Name=item['snippet']['channelTitle'],
                                PublishedAt=item['snippet']['publishedAt'],
                                Video_Count=item['contentDetails']['itemCount'])
                        
                        All_data.append(data)

                next_page_token=response.get('nextPageToken')
                if next_page_token is None:
                        break
        return All_data

# %%
playlist_details=get_playlist_details('UC2J_VKrAzOEJuQvFFtj3KUw')

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PL7GssaCNTMlkTSuQvSmc6QHhSG_3vBv3r',
#   'Title': 'Whistles from Chepauk - CWC 2023',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2023-11-02T05:47:29Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PL7GssaCNTMlljlbRj9I2y_Yuv71aMoHMn',
#   'Title': 'Cricket with Badri - CWC 2023',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2023-11-02T05:43:57Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PL7GssaCNTMlmMDJBkpdDn-CcjXFuq0rxI',
#   'Title': 'Gripping Stories',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-07-22T11:26:35Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PL7GssaCNTMlmyqaq_HjLIgyiIbSe9OmjQ',
#   'Title': 'Team Mates',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-07-22T11:21:15Z',
#   'Video_Count': 3},
#  {'Playlist_Id': 'PL7GssaCNTMlltZdJFQ6ONWdmFILDPzomS',
#   'Title': 'First Time in Yellove - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:10:34Z',
#   'Video_Count': 9},
#  {'Playlist_Id': 'PL7GssaCNTMlnIpq7uDNVruyU__KmBP9Gy',
#   'Title': 'Candid Super Kings - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:07:34Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PL7GssaCNTMlnNRqa12s7p51x6uI9yNiNO',
#   'Title': 'Super Practice - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:07:14Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PL7GssaCNTMlltI4ObEFO_KyzzCIlBuhVL',
#   'Title': 'Anbuden Diaries - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:06:15Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PL7GssaCNTMlkBJu0aMuMw1Oq409odv0q6',
#   'Title': 'Post Match 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T18:50:28Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PL7GssaCNTMll3CZy_6H2RvNJ83o0NvLhn',
#   'Title': 'Super Auction 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2022-02-11T12:23:58Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PL7GssaCNTMlkZbFDiTvhcxmDBzR3RNYjU',
#   'Title': 'Super Fans',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:39:15Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PL7GssaCNTMlkPDzG_3_n4YYGHr48Y3jJa',
#   'Title': 'Everywhere We Go',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:37:02Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PL7GssaCNTMlla9utBgjzg44-qtpE6IF4k',
#   'Title': 'Super Fam Super Fun',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:34:39Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PL7GssaCNTMlkA1w-zWCeNe5CS_OY24esp',
#   'Title': 'CubG Squad',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:31:11Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PL7GssaCNTMllUTj8cdOPZyxZ3f1fnx4qS',
#   'Title': 'Super Couple - 2021',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:59:27Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PL7GssaCNTMlmMho_iVGWCCvg8_00bcy95',
#   'Title': 'Super Coach',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:58:34Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PL7GssaCNTMlmzmd5KygjwC7Dmya11MaRc',
#   'Title': 'Super Birthday',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:57:57Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PL7GssaCNTMlk64TPwWDpIfU_7wfYIQ_CY',
#   'Title': 'Style Quotient',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:53:09Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PL7GssaCNTMlnFGn9inw_5wrbXSKGryctj',
#   'Title': 'The Pride of 2021',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-10-29T06:12:02Z',
#   'Video_Count': 29},
#  {'Playlist_Id': 'PL7GssaCNTMlnnF5y3MAgCTua9HlrZnhle',
#   'Title': "What's On Your Screen",
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-12T08:46:41Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PL7GssaCNTMllbsBhk5n2mo-1CqH7ls-wG',
#   'Title': 'AnbuDen Diaries',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-12T06:52:45Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PL7GssaCNTMll7PMPcuCN3ErR8JfejaHne',
#   'Title': 'Post Match Round-Up',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-11T10:51:02Z',
#   'Video_Count': 3},
#  {'Playlist_Id': 'PL7GssaCNTMlk6HTrxzImX_bM_xvhdLpGI',
#   'Title': 'Pre Match Build Up',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-10T06:25:12Z',
#   'Video_Count': 3},
#  {'Playlist_Id': 'PL7GssaCNTMlmdBzUZKWnUJGTE5KyYCeWL',
#   'Title': 'Picture Perfect',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-09T10:33:04Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PL7GssaCNTMlkvoAraB-KbsWAEvOGIB3S3',
#   'Title': 'KINGS ARENA',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-08T11:24:44Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PL7GssaCNTMlkrtMv5D6W8qY84bM54M7cw',
#   'Title': 'Super Auction 2021!',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2021-02-21T15:01:38Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PL7GssaCNTMlmolU8thAvM7wPBdPGIgBBQ',
#   'Title': 'Super Local Challenge',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2020-10-15T05:51:21Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PL7GssaCNTMlmGgeU_prRPrhh9JXTI2cjO',
#   'Title': 'With Yellove!',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2020-09-16T03:20:16Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PL7GssaCNTMlmu5ROjSLJ6Iiizs_WsyYIH',
#   'Title': 'AnbuDen Lions',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2020-04-15T17:35:22Z',
#   'Video_Count': 15},
#  {'Playlist_Id': 'PL7GssaCNTMllSsa0TLdWKSDjLtnhvUYjU',
#   'Title': 'Deepavali Release',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2019-10-27T02:02:19Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'FL2J_VKrAzOEJuQvFFtj3KUw',
#   'Title': 'Favorites',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_Name': 'Chennai Super Kings',
#   'PublishedAt': '2011-04-20T15:27:52Z',
#   'Video_Count': 1}]

# %%
len(playlist_details)
# Out:
# 31

# %%
# Upload to MongoDB

client=pymongo.MongoClient("mongodb://localhost:27017")
db=client["Youtube_data"]

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,
                      "playlist_information":pl_details,
                      "video_information":vi_details,
                      "comment_information":com_details
                      })
    return"upload completed successfully"

# %%
#science with sam : UChGd9JY4yMegY6PxqpBjpRA
#mr Gk : UC5cY198GU1MQMIPJgMkCJ_Q
#TBP : UCy1lBBbXhtfzugF_LK2b6Yw
#Tech Scratch: UCUgZ-UO8QliyZ4QB0R7xCQA

# %%
insert=channel_details("UChGd9JY4yMegY6PxqpBjpRA")

# %%
insert=channel_details("UC5cY198GU1MQMIPJgMkCJ_Q")

# %%
insert=channel_details("UCy1lBBbXhtfzugF_LK2b6Yw")

# %%
insert=channel_details("UCUgZ-UO8QliyZ4QB0R7xCQA")

# %%
# Table creation for channels,Playlists,videos,comments
def channels_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="sql@123",
                        database="youtube_data",
                        port="5432"
                        )
    cursor=mydb.cursor()

    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(Channel_name varchar(100),
                                                                Channel_Id varchar(80) primary key,
                                                                Subscribers bigint,
                                                                Views bigint,
                                                                Total_Videos int,
                                                                Channel_Description text,
                                                                Playlist_Id varchar(80))'''
        cursor.execute(create_query)
        mydb.commit()

    except:
        print("Channels table already created")


    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},
                            {"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=pd.DataFrame(ch_list)


    for index,row in df.iterrows():
        insert_query='''insert into channels(Channel_name,
                                            Channel_Id,
                                            Subscribers,
                                            Views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_Id)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_name'],
                row['Channel_Id'],
                row['Subscribers'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row ['Playlist_Id'])
        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("Channels values are already inserted")

# %%
# Table creation for Playlists

def playlist_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="sql@123",
                        database="youtube_data",
                        port="5432"
                        )
    cursor=mydb.cursor()

    drop_query='''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                            Title varchar(80),
                                                            Channel_Id varchar(100),
                                                            Channel_Name varchar(100),
                                                            PublishedAt timestamp,
                                                            Video_Count int
                                                            )'''

    cursor.execute(create_query)
    mydb.commit()

    pl_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
            for i in range(len(pl_data["playlist_information"])):
                pl_list.append(pl_data["playlist_information"][i])
    df1=pd.DataFrame(pl_list)

    

    for index,row in df1.iterrows():
        insert_query='''insert into playlists(Playlist_Id,
                                          Title,
                                          Channel_Id,
                                          Channel_Name,
                                          PublishedAt,
                                          Video_Count)
                                    
                                    values(%s,%s,%s,%s,%s,%s)'''
        values=(row['Playlist_Id'],
                row['Title'],
                row['Channel_Id'],
                row['Channel_Name'],
                row['PublishedAt'],
                row['Video_Count'])

        cursor.execute(insert_query,values)
        mydb.commit()

# %%
def videos_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="sql@123",
                        database="youtube_data",
                        port="5432"
                        )
    cursor=mydb.cursor()

    drop_query='''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists videos(channel_Name varchar(100),
                                                    channelId varchar(100),
                                                    Video_id varchar(30) primary key,
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumnail varchar(200),
                                                    Description text,
                                                    Published_Date timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favourite_count int,
                                                    Definition varchar(10),
                                                    Caption_status varchar(50)
                                                    )'''

    cursor.execute(create_query)
    mydb.commit()

    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
            for i in range(len(vi_data["video_information"])):
                vi_list.append(vi_data["video_information"][i])
    df2=pd.DataFrame(vi_list)





    for index,row in df2.iterrows():
        insert_query='''insert into videos(channel_Name,
                                            channelId,
                                            Video_id,
                                            Title,
                                            Tags,
                                            Thumnail,
                                            Description,
                                            Published_Date,
                                            Duration,
                                            Views,
                                            Likes,
                                            Comments,
                                            Favourite_count,
                                            Definition,
                                            Caption_status
                                            )

                                
                                            values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
        

    
        
        values=(row['channel_Name'],
                row['channelId'],
                row['Video_id'],
                row['Title'],
                row['Tags'],
                row['Thumnail'],
                row['Description'],
                row['Published_Date'],
                row['Duration'],
                row['Views'],
                row['Likes'],
                row['Comments'],
                row['Favourite_count'],
                row['Definition'],
                row['Caption_status'])

        cursor.execute(insert_query,values)
        mydb.commit()

# %%
def comments_tables():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="sql@123",
                        database="youtube_data",
                        port="5432"
                        )
    cursor=mydb.cursor()

    drop_query='''drop table if exists lcomments'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists comments(Comment_Id varchar(100),
                                                Video_Id varchar(50),
                                                Comment_Text text,
                                                Comment_Author varchar(150),
                                                Comment_Published timestamp
                                                            )'''

    cursor.execute(create_query)
    mydb.commit()

    com_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
            for i in range(len(com_data["comment_information"])):
                com_list.append(com_data["comment_information"][i])
    df3=pd.DataFrame(com_list)

    for index,row in df3.iterrows():
            insert_query='''insert into comments(Comment_Id,
                                                    Video_Id,
                                                    Comment_Text,
                                                    Comment_Author,
                                                    Comment_Published
                                                    )
                                        
                                        values(%s,%s,%s,%s,%s)'''
            values=(row['Comment_Id'],
                    row['Video_Id'],
                    row[ 'Comment_Text'],
                    row['Comment_Author'],
                    row['Comment_Published']
                )
            
        

            cursor.execute(insert_query,values)
            mydb.commit()

# %%
def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_tables()

    return"Table Created Sucessfully"

# %%
Tables=tables()

# %%
Tables
# Out:
# 'Table Created Sucessfully'

# %%
def show_channels_table():
    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},
                            {"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=st.dataframe(ch_list)

    return df

# %%
def show_playlists_table():
    pl_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
            for i in range(len(vi_data["video_information"])):
                vi_list.append(vi_data["video_information"][i])
    df2=st.dataframe(vi_list)

    return df2

# %%
def show_comments_table():
    com_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
            for i in range(len(com_data["comment_information"])):
                com_list.append(com_data["comment_information"][i])
    df3=st.dataframe(com_list)

    return df3

# %%
# Streamlit part

with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("Skill Take Away")
    st.caption("Python Scripting")
    st.caption("Data Collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management using MongoDB and SQL")

# Getting Input from user

channel_id=st.text_input("Enter the channel ID")

if st.button("Collect and Store Data"):
    ch_ids=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]

    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel_information"]["Channel_Id"])

    if channel_id in ch_ids:
        st.success("Channel Details of given channel id already exists")

    else:
        insert=channel_details(channel_id)
        st.success(insert)
    
if st.button("Migrate to SQL"):
    Table=tables()
    st.success(Table)

show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table=="CHANNELS":
    show_channels_table()

elif show_table=="PLAYLISTS":
    show_playlists_table()

elif show_table=="VIDEOS":
    show_videos_table()

elif show_table=="COMMENTS":
    show_comments_table()

# %%
# SQL CONNECTION

mydb=psycopg2.connect(host="localhost",
                    user="postgres",
                    password="sql@123",
                    database="youtube_data",
                    port="5432"
                    )
cursor=mydb.cursor()

question=st.selectbox("Select your question",("1. All the videos and the channel name",
                                              "2. Channels with most number of videos",
                                              "3. 10 most viewed videos" ,
                                              "4. Comments in each videos",
                                              "5. Videos with highest likes",
                                              "6. Likes of all videos",
                                              "7. Views of each Channel",
                                              "8. Videos published in the year of 2022",
                                              "9. Average duration of all videos in each channel",
                                              "10. Videos with highest number of comments"))

if question=="1. All the videos and the channel name":

    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)

elif question=="2. Channels with most number of videos":

    query2='''select channel_name as channelname,total_videos as no_videos from channels
                order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2=pd.DataFrame(t2,columns=["channel name","No of videos"])
    st.write(df2)

elif question=="3. 10 most viewed videos":

    query3='''select views as views,channel_name as channelname,title as videotitle from videos
                where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["Views","channel name","videotitle"])
    st.write(df3)

elif question=="4. Comments in each videos":

    query4='''select comments as no_comments,title as videotitle from videos where comments is not null'''
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.write(df4)

elif question=="5. Videos with highest likes":

    query5='''select title as videotitle,channel_name as channelname,likes as likecount
                from videos where likes is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.write(df5)

elif question=="6. Likes of all videos":

    query6='''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["likecount","videotitle"])
    st.write(df6)

elif question=="7. Views of each Channel":

    query7='''select channel_name as channelname,views as totalviews from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channel_name","total views"])
    st.write(df7)

elif question=="8. Videos published in the year of 2022":

    query8='''select title as video_title,published_date as videorelease,channel_name as channelname from videos
                where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["videotitle","published_date","channelname"])
    st.write(df8)

elif question=="9. Average duration of all videos in each channel":

    query9='''select channel_name as channelname,AVG(duration) as averageduration from videos group by channel_name'''
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["channelname","averageduration"])
    
    df9

    T9=[]
    for index,row in df9.iterrows():
        channel_title=row["channelname"]
        average_duration=row["averageduration"]
        average_duration_str=str(average_duration)
        T9.append(dict(channeltitle=channel_title,avgduration=average_duration_str))
    df1=pd.DataFrame(T9)
    st.write(df9)

    
elif question=="10. Videos with highest number of comments":

    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos
                where comments is not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["videotitle","channel_name","comments"])
    st.write(df10)
